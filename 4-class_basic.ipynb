# %% [markdown]
# **The first thing to do is to run Creator.py to setup the dataset. First specify the options**

# %%
import numpy as np
# The Name of the Dataset
Name = 'Class_4/Class_4_500-inv'

# Frequency Array
Frequencies=np.array([119.25,178.875,238.5,298.125,357.75,477,596.25,715.5,954,1192.5,1431,1908,2385,2862,3816,4770,5724,7632,9540,12402,16218,20988,26712,34344,43884,57240,73458,95400])
Frequencies = Frequencies*6.28 #Convert to rad/s'

# Classes to Include

Classes = ['British_Coins_Updated_1p_2p','Knives','Pendants','Screwdrivers']
#(list) list of strings for the classes to be included in the training set
#this is hierarchic so includes all subclasses of a given class. Can also
#be 'all' to include all classes.

# Global number of results
#8 and 15 class problem
extend_results = 'global_class'
#(string) 'global_obj','global_class' or 'classwise' if 'objectwise' required use scaling file


# Number of secondary results if 'global_obj'
Num_Results = 500

# Classes if 'global_class' or 'classwise'
#8 class
class_split = ['British_Coins_Updated_1p_2p','Pendants','Knives','Screwdrivers']


# Name each of the classes this is done in order
# 8 class
class_names = ['British Coins','Pendants','Knives','Screwdrivers']


# Number of results if 'global_class'
# 8 and 15 class problem
Num_Results_class = 500

# (int) Number of results per class results per class if 'classwise'
class_num_results = [500,500,500,500]

#Labeler False,'Classwise', 'Objectwise'
#8 and 15 class
Label_Data = 'Classwise'
#(boolean or string) create training labels for the dataset

#If Label_Data = 'Objectwise' you can create a dictionary of names for each object
Name_Objects = []

#(dictionary) name the objects as you wish them to appear in the classificaiton
Object_Names_dictionary =[]

Name_Order = ['British Coins','Pendants','Knives','Screwdrivers']


#How to scale
Scale_type = 'Global'

#Which file (This is not currently used)
Scale_File = 'Coin_DataSet.csv'


#Alpha scale
Alpha_scale = 0.84 # original scaling

#Sigma scale
Sigma_scale = 2.4 # original scaling

#From paper s_alpha = 8.4e-6 to obtain: Alpha_scale = (s_alpha/alpha)*100
#From paper s_sigma = 9.52e5 to obtain: Sigma_scale = (s_sigma/sigma)*100

# Path Name for where the class data is stored
Class_dir = "Classes_Paul"

# Make plot of first two reduced invairants
Plot_Principal_Componenets = False

# Create a dictionary of these settings
Creator_Settings = {"Name":Name,"Frequencies":Frequencies,"Classes":Classes,"extend_results":extend_results,"Num_Results":Num_Results,#
                    "class_split":class_split,"class_names":class_names,"Num_Results_class":Num_Results_class,"class_num_results":class_num_results,\
                    "Label_Data":Label_Data,"Name_Objects":Name_Objects,"Object_Names_dictionary":Object_Names_dictionary,"Name_Order":Name_Order,\
                    "Scale_type":Scale_type,"Scale_File":Scale_File,"Alpha_scale":Alpha_scale,"Sigma_scale":Sigma_scale, "Class_dir": Class_dir}

# %%
# Run the Creator script
from Creator import *
DataSet_Name=Creator(Creator_Settings)
# Out:
# The folder path to the dataset is: Class_4/Class_4_500-inv_Al_0.84_Sig_2.4
# Class type is a list
# Long_circular_plushead_stainlesssteel_shaft_stainlesssteel
# Regular_circular_plushead_stainlesssteel_shaft_stainlesssteel
# Long_circular_plushead_stainlesssteel_shaft_titanium
# Long_circular_flathead_stainlesssteel_shaft_titanium
# Regular_circular_flathead_stainlesssteel_shaft_titanium
# Short_circular_flathead_stainlesssteel_shaft_titanium
# Regular_circular_plushead_stainlesssteel_shaft_titanium
# Short_circular_plushead_stainlesssteel_shaft_titanium
# Regular_circular_flathead_stainlesssteel_shaft_stainlesssteel
# Short_circular_plushead_stainlesssteel_shaft_stainlesssteel
# Short_circular_flathead_stainlesssteel_shaft_stainlesssteel
# Long_circular_flathead_stainlesssteel_shaft_stainlesssteel
# Knife_Wusthof
# Knife_Santoku
# Knife_Cleaver_Magnetic
# Knife_Wusthof_Magnetic
# Knife_Santoku_Magnetic
# Knife_Cleaver
# Knife_Cheap_Cutlet_Magnetic
# Knife_Cheap_Chef
# Knife_Cheap_Chef_Magnetic
# Knife_Cheap_Cutlet
# Heart_pendant
# Oval_pendant
# Cross
# Rectangle_pendant
# Cross_with_bail
# Soverign_pendant_with_bail
# Soverign_pendant
# Five_Pence_non_magnetic
# One_Pound
# Two_Penny
# Two_Penny_non_magnetic
# Two_Pound
# Five_Pence
# One_Penny_non_magnetic
# Ten_Pence_non_magnetic
# Twenty_Pence
# Ten_Pence
# Fifty_Pence
# One_Penny
# (2018, 28) 28

# %%
# This is the dataset name to be used with the classifier
DataSet_Name="Class_4/Class_4_500-inv_Al_0.84_Sig_2.4"
print(DataSet_Name)
# Out:
# Class_4/Class_4_500-inv_Al_0.84_Sig_2.4

# %% [markdown]
# **The next part involves running the actual classifier. This is done using Trainer_PDL.py**

# %%
# Option to load external testing data from disk. Requires that external_file_loader.py be run first.
Load_External_Data = False 
# Option to plot comparison figures between the input array of simulated data and the external test data.
# Currently only supported for a single class test set.
Plot_Comparison_Figures = False
# Option to additionally save to disk: the model for each bootstrap iteration, the normalisation coefficients for each,
# bootstrap iteration, and the input array for each model, Used for debugging.
Full_Save = False

# Option to use SVD to reduce the number of features
Reduce_Features = True

#Model to be used
#Optional models 'LogisticRegression', 'SVM', 'DecisionTree', 'RandomForest', 'GradientBoost', 'MLP','MLP,(n1,n2,...,nn)'
Models_to_run =["ProbFlowNN_Bayesian_Opt"]#["LogisticRegression_Bayesian"]# ['LogisticRegression']

#Features
Features = ['Pri1', 'Pri2', 'Pri3','AngleRtildeI']#
# Features = ['Eig1', 'Eig2', 'Eig3']
#(list) list of features to be used options:
#'Eig1','Eig2','Eig3','Pri1','Pri2','Pri3','Dev2','Dev3','Com'
#Eigenvalues, Principal invarients, Deviatoric invarients, Comutator

#How many times would you like to train the model
Bootstrap_Repetitions = 1
#(int) how many times to train the model to obtain an average accuracy

# use default levels of SNR
SNR_array=[]

# Make plot of first two reduced invairants
Plot_Principal_Componenets = True

Trainer_Settings = {"DataSet_Name": DataSet_Name, "Load_External_Data":Load_External_Data, "Plot_Comparison_Figures":Plot_Comparison_Figures,\
                   "Full_Save": Full_Save, "Reduce_Features":Reduce_Features, "Models_to_run": Models_to_run, "Features":Features,
                    "Bootstrap_Repetitions": Bootstrap_Repetitions, "SNR_array": SNR_array,"Plot_Principal_Componenets":Plot_Principal_Componenets }

# %%
from Trainer_PDL import *

main(Trainer_Settings)
# Out:
# 2024-05-16 15:04:16.595903: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-16 15:04:16.597633: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-16 15:04:16.631511: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-16 15:04:16.632292: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-16 15:04:17.220908: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Noise level =  5
# (2018, 504)
# (2018, 198) (2018, 196)
# Data [[6.00075816e-06 5.95902774e-06 5.90396005e-06 ... 1.83015119e-03
#   2.99616737e-03 6.41778648e-03]
#  [6.00075816e-06 5.95902774e-06 5.90396005e-06 ... 2.16564992e-03
#   3.36903395e-03 8.32062569e-03]
#  [6.00075816e-06 5.95902774e-06 5.90396005e-06 ... 1.53143821e-03
#   2.77195924e-03 5.48686101e-03]
#  ...
#  [5.78392560e-07 5.68245963e-07 5.56157557e-07 ... 5.23440569e-04
#   5.99439860e-04 6.32957574e-04]
#  [5.78392560e-07 5.68245963e-07 5.56157557e-07 ... 5.02611821e-04
#   5.89297468e-04 6.29611191e-04]
#  [5.78392560e-07 5.68245963e-07 5.56157557e-07 ... 5.17931133e-04
#   5.96782341e-04 6.32131101e-04]]
# to here
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Noise_adder.py:30: RuntimeWarning: divide by zero encountered in log10
#   sig_db = 10 * np.log10(sig_watts)
# ProbFlowNN_Bayesian_Opt
# 1513 196
#  SVD complete
# Reduced the number of features from 196  to  138
# (1513, 138)
# (1513,)
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Plot_principal_features.py:50: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sactter_plot = sns.scatterplot(data=internal_dataframe, x='Reduced Feature 1', y = 'Reduced Feature 2', hue='Class Names', palette=palette, hue_order=reordered_names)
# Performing hyper parameter search
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [16] 0.9345670852610707
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [37, 37] 0.9933906146728354
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [51, 51] 0.9980171844018506
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [53, 53] 0.9993390614672836
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [44, 44] 0.9980171844018506
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [35] 0.9610046265697291
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [32, 32] 0.9933906146728354
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [49] 0.9563780568407139
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [46, 46] 0.9960343688037012
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [20, 20] 0.9808327825512227
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [37, 37] 0.9933906146728354
# [64, 64, 64] 1.0
# [54, 54, 54] 1.0
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [16, 16, 16] 0.9933906146728354
# [41, 41, 41] 1.0
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [64, 64] 0.9980171844018506
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [59, 59] 0.9993390614672836
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [29, 29, 29] 1.0
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [3, 64] before, using random point [3, 21]
#   warnings.warn(
# [64] 0.9524124256444151
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [3, 64] before, using random point [2, 61]
#   warnings.warn(
# [21, 21, 21] 0.9993390614672836
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [61, 61] 0.998678122934567
# [59, 59, 59] 1.0
# [47, 47, 47] 1.0
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [2, 59] before, using random point [2, 64]
#   warnings.warn(
# [34, 34, 34] 0.9993390614672836
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [64, 64] 0.9980171844018506
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [2, 58] before, using random point [2, 59]
#   warnings.warn(
# [58, 58] 0.9993390614672836
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [3, 64] before, using random point [3, 50]
#   warnings.warn(
# [59, 59] 0.9993390614672836
# [50, 50, 50] 1.0
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [3, 64] before, using random point [2, 51]
#   warnings.warn(
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [3, 64] before, using random point [2, 54]
#   warnings.warn(
# [51, 51] 0.9980171844018506
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2024-05-16 15:05:15.345576: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# [54, 54] 0.9993390614672836
# Found optimumum settings
# [3, 64]
# 0.0
# Item 1  of  505
# Completed posterior plots
#              Class     Post_prob
# 0    British Coins  0.000000e+00
# 1    British Coins  0.000000e+00
# 2    British Coins  0.000000e+00
# 3    British Coins  7.276820e-07
# 4    British Coins  0.000000e+00
# ..             ...           ...
# 395   Screwdrivers  1.000000e+00
# 396   Screwdrivers  1.000000e+00
# 397   Screwdrivers  1.000000e+00
# 398   Screwdrivers  1.000000e+00
# 399   Screwdrivers  1.000000e+00
#
# [400 rows x 2 columns]
# Item 2  of  505
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:265: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(data=df, x="Post_prob",y="Class",cut=0,scale="width")
# Completed posterior plots
#              Class     Post_prob
# 0    British Coins  1.960743e-02
# 1    British Coins  7.669386e-03
# 2    British Coins  4.509209e-02
# 3    British Coins  1.301811e-03
# 4    British Coins  1.024897e-03
# ..             ...           ...
# 395   Screwdrivers  6.378623e-09
# 396   Screwdrivers  1.054424e-02
# 397   Screwdrivers  3.601024e-06
# 398   Screwdrivers  4.758207e-05
# 399   Screwdrivers  2.982554e-06
#
# [400 rows x 2 columns]
# Item 3  of  505
# Item 4  of  505
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:265: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(data=df, x="Post_prob",y="Class",cut=0,scale="width")
# Completed posterior plots
#              Class  Post_prob
# 0    British Coins   0.866895
# 1    British Coins   0.594860
# 2    British Coins   0.685020
# 3    British Coins   0.918273
# 4    British Coins   0.954269
# ..             ...        ...
# 395   Screwdrivers   0.000261
# 396   Screwdrivers   0.000006
# 397   Screwdrivers   0.000013
# 398   Screwdrivers   0.000031
# 399   Screwdrivers   0.000039
#
# [400 rows x 2 columns]
# Item 5  of  505
# Item 6  of  505
# Item 7  of  505
# Item 8  of  505
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:265: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(data=df, x="Post_prob",y="Class",cut=0,scale="width")
# Item 9  of  505
# Item 10  of  505
# Item 11  of  505
# Item 12  of  505
# Item 13  of  505
# Item 14  of  505
# Item 15  of  505
# Item 16  of  505
# Completed posterior plots
#              Class     Post_prob
# 0    British Coins  0.000000e+00
# 1    British Coins  1.160826e-06
# 2    British Coins  0.000000e+00
# 3    British Coins  3.470822e-07
# 4    British Coins  0.000000e+00
# ..             ...           ...
# 395   Screwdrivers  0.000000e+00
# 396   Screwdrivers  0.000000e+00
# 397   Screwdrivers  0.000000e+00
# 398   Screwdrivers  0.000000e+00
# 399   Screwdrivers  0.000000e+00
#
# [400 rows x 2 columns]
# Item 17  of  505
# Item 18  of  505
# Item 19  of  505
# Item 20  of  505
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:265: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(data=df, x="Post_prob",y="Class",cut=0,scale="width")
# Item 21  of  505
# Item 22  of  505
# Item 23  of  505
# Item 24  of  505
# Item 25  of  505
# Item 26  of  505
# Item 27  of  505
# Item 28  of  505
# Item 29  of  505
# Item 30  of  505
# Item 31  of  505
# Item 32  of  505
# Item 33  of  505
# Item 34  of  505
# Item 35  of  505
# Item 36  of  505
# Item 37  of  505
# Item 38  of  505
# Item 39  of  505
# Item 40  of  505
# Item 41  of  505
# Item 42  of  505
# Item 43  of  505
# Item 44  of  505
# Item 45  of  505
# Item 46  of  505
# Item 47  of  505
# Item 48  of  505
# Item 49  of  505
# Item 50  of  505
# Item 51  of  505
# Item 52  of  505
# Item 53  of  505
# Item 54  of  505
# Item 55  of  505
# Item 56  of  505
# Item 57  of  505
# Item 58  of  505
# Item 59  of  505
# Item 60  of  505
# Item 61  of  505
# Item 62  of  505
# Item 63  of  505
# Item 64  of  505
# Item 65  of  505
# Item 66  of  505
# Item 67  of  505
# Item 68  of  505
# Item 69  of  505
# Item 70  of  505
# Item 71  of  505
# Item 72  of  505
# Item 73  of  505
# Item 74  of  505
# Item 75  of  505
# Item 76  of  505
# Item 77  of  505
# Item 78  of  505
# Item 79  of  505
# Item 80  of  505
# Item 81  of  505
# Item 82  of  505
# Item 83  of  505
# Item 84  of  505
# Item 85  of  505
# Item 86  of  505
# Item 87  of  505
# Item 88  of  505
# Item 89  of  505
# Item 90  of  505
# Item 91  of  505
# Item 92  of  505
# Item 93  of  505
# Item 94  of  505
# Item 95  of  505
# Item 96  of  505
# Item 97  of  505
# Item 98  of  505
# Item 99  of  505
# Item 100  of  505
# Item 101  of  505
# Item 102  of  505
# Item 103  of  505
# Item 104  of  505
# Item 105  of  505
# Item 106  of  505
# Item 107  of  505
# Item 108  of  505
# Item 109  of  505
# Item 110  of  505
# Item 111  of  505
# Item 112  of  505
# Item 113  of  505
# Item 114  of  505
# Item 115  of  505
# Item 116  of  505
# Item 117  of  505
# Item 118  of  505
# Item 119  of  505
# Item 120  of  505
# Item 121  of  505
# Item 122  of  505
# Item 123  of  505
# Item 124  of  505
# Item 125  of  505
# Item 126  of  505
# Item 127  of  505
# Item 128  of  505
# Item 129  of  505
# Item 130  of  505
# Item 131  of  505
# Item 132  of  505
# Item 133  of  505
# Item 134  of  505
# Item 135  of  505
# Item 136  of  505
# Item 137  of  505
# Item 138  of  505
# Item 139  of  505
# Item 140  of  505
# Item 141  of  505
# Item 142  of  505
# Item 143  of  505
# Item 144  of  505
# Item 145  of  505
# Item 146  of  505
# Item 147  of  505
# Item 148  of  505
# Item 149  of  505
# Item 150  of  505
# Item 151  of  505
# Item 152  of  505
# Item 153  of  505
# Item 154  of  505
# Item 155  of  505
# Item 156  of  505
# Item 157  of  505
# Item 158  of  505
# Item 159  of  505
# Item 160  of  505
# Item 161  of  505
# Item 162  of  505
# Item 163  of  505
# Item 164  of  505
# Item 165  of  505
# Item 166  of  505
# Item 167  of  505
# Item 168  of  505
# Item 169  of  505
# Item 170  of  505
# Item 171  of  505
# Item 172  of  505
# Item 173  of  505
# Item 174  of  505
# Item 175  of  505
# Item 176  of  505
# Item 177  of  505
# Item 178  of  505
# Item 179  of  505
# Item 180  of  505
# Item 181  of  505
# Item 182  of  505
# Item 183  of  505
# Item 184  of  505
# Item 185  of  505
# Item 186  of  505
# Item 187  of  505
# Item 188  of  505
# Item 189  of  505
# Item 190  of  505
# Item 191  of  505
# Item 192  of  505
# Item 193  of  505
# Item 194  of  505
# Item 195  of  505
# Item 196  of  505
# Item 197  of  505
# Item 198  of  505
# Item 199  of  505
# Item 200  of  505
# Item 201  of  505
# Item 202  of  505
# Item 203  of  505
# Item 204  of  505
# Item 205  of  505
# Item 206  of  505
# Item 207  of  505
# Item 208  of  505
# Item 209  of  505
# Item 210  of  505
# Item 211  of  505
# Item 212  of  505
# Item 213  of  505
# Item 214  of  505
# Item 215  of  505
# Item 216  of  505
# Item 217  of  505
# Item 218  of  505
# Item 219  of  505
# Item 220  of  505
# Item 221  of  505
# Item 222  of  505
# Item 223  of  505
# Item 224  of  505
# Item 225  of  505
# Item 226  of  505
# Item 227  of  505
# Item 228  of  505
# Item 229  of  505
# Item 230  of  505
# Item 231  of  505
# Item 232  of  505
# Item 233  of  505
# Item 234  of  505
# Item 235  of  505
# Item 236  of  505
# Item 237  of  505
# Item 238  of  505
# Item 239  of  505
# Item 240  of  505
# Item 241  of  505
# Item 242  of  505
# Item 243  of  505
# Item 244  of  505
# Item 245  of  505
# Item 246  of  505
# Item 247  of  505
# Item 248  of  505
# Item 249  of  505
# Item 250  of  505
# Item 251  of  505
# Item 252  of  505
# Item 253  of  505
# Item 254  of  505
# Item 255  of  505
# Item 256  of  505
# Item 257  of  505
# Item 258  of  505
# Item 259  of  505
# Item 260  of  505
# Item 261  of  505
# Item 262  of  505
# Item 263  of  505
# Item 264  of  505
# Item 265  of  505
# Item 266  of  505
# Item 267  of  505
# Item 268  of  505
# Item 269  of  505
# Item 270  of  505
# Item 271  of  505
# Item 272  of  505
# Item 273  of  505
# Item 274  of  505
# Item 275  of  505
# Item 276  of  505
# Item 277  of  505
# Item 278  of  505
# Item 279  of  505
# Item 280  of  505
# Item 281  of  505
# Item 282  of  505
# Item 283  of  505
# Item 284  of  505
# Item 285  of  505
# Item 286  of  505
# Item 287  of  505
# Item 288  of  505
# Item 289  of  505
# Item 290  of  505
# Item 291  of  505
# Item 292  of  505
# Item 293  of  505
# Item 294  of  505
# Item 295  of  505
# Item 296  of  505
# Item 297  of  505
# Item 298  of  505
# Item 299  of  505
# Item 300  of  505
# Item 301  of  505
# Item 302  of  505
# Item 303  of  505
# Item 304  of  505
# Item 305  of  505
# Item 306  of  505
# Item 307  of  505
# Item 308  of  505
# Item 309  of  505
# Item 310  of  505
# Item 311  of  505
# Item 312  of  505
# Item 313  of  505
# Item 314  of  505
# Item 315  of  505
# Item 316  of  505
# Item 317  of  505
# Item 318  of  505
# Item 319  of  505
# Item 320  of  505
# Item 321  of  505
# Item 322  of  505
# Item 323  of  505
# Item 324  of  505
# Item 325  of  505
# Item 326  of  505
# Item 327  of  505
# Item 328  of  505
# Item 329  of  505
# Item 330  of  505
# Item 331  of  505
# Item 332  of  505
# Item 333  of  505
# Item 334  of  505
# Item 335  of  505
# Item 336  of  505
# Item 337  of  505
# Item 338  of  505
# Item 339  of  505
# Item 340  of  505
# Item 341  of  505
# Item 342  of  505
# Item 343  of  505
# Item 344  of  505
# Item 345  of  505
# Item 346  of  505
# Item 347  of  505
# Item 348  of  505
# Item 349  of  505
# Item 350  of  505
# Item 351  of  505
# Item 352  of  505
# Item 353  of  505
# Item 354  of  505
# Item 355  of  505
# Item 356  of  505
# Item 357  of  505
# Item 358  of  505
# Item 359  of  505
# Item 360  of  505
# Item 361  of  505
# Item 362  of  505
# Item 363  of  505
# Item 364  of  505
# Item 365  of  505
# Item 366  of  505
# Item 367  of  505
# Item 368  of  505
# Item 369  of  505
# Item 370  of  505
# Item 371  of  505
# Item 372  of  505
# Item 373  of  505
# Item 374  of  505
# Item 375  of  505
# Item 376  of  505
# Item 377  of  505
# Item 378  of  505
# Item 379  of  505
# Item 380  of  505
# Item 381  of  505
# Item 382  of  505
# Item 383  of  505
# Item 384  of  505
# Item 385  of  505
# Item 386  of  505
# Item 387  of  505
# Item 388  of  505
# Item 389  of  505
# Item 390  of  505
# Item 391  of  505
# Item 392  of  505
# Item 393  of  505
# Item 394  of  505
# Item 395  of  505
# Item 396  of  505
# Item 397  of  505
# Item 398  of  505
# Item 399  of  505
# Item 400  of  505
# Item 401  of  505
# Item 402  of  505
# Item 403  of  505
# Item 404  of  505
# Item 405  of  505
# Item 406  of  505
# Item 407  of  505
# Item 408  of  505
# Item 409  of  505
# Item 410  of  505
# Item 411  of  505
# Item 412  of  505
# Item 413  of  505
# Item 414  of  505
# Item 415  of  505
# Item 416  of  505
# Item 417  of  505
# Item 418  of  505
# Item 419  of  505
# Item 420  of  505
# Item 421  of  505
# Item 422  of  505
# Item 423  of  505
# Item 424  of  505
# Item 425  of  505
# Item 426  of  505
# Item 427  of  505
# Item 428  of  505
# Item 429  of  505
# Item 430  of  505
# Item 431  of  505
# Item 432  of  505
# Item 433  of  505
# Item 434  of  505
# Item 435  of  505
# Item 436  of  505
# Item 437  of  505
# Item 438  of  505
# Item 439  of  505
# Item 440  of  505
# Item 441  of  505
# Item 442  of  505
# Item 443  of  505
# Item 444  of  505
# Item 445  of  505
# Item 446  of  505
# Item 447  of  505
# Item 448  of  505
# Item 449  of  505
# Item 450  of  505
# Item 451  of  505
# Item 452  of  505
# Item 453  of  505
# Item 454  of  505
# Item 455  of  505
# Item 456  of  505
# Item 457  of  505
# Item 458  of  505
# Item 459  of  505
# Item 460  of  505
# Item 461  of  505
# Item 462  of  505
# Item 463  of  505
# Item 464  of  505
# Item 465  of  505
# Item 466  of  505
# Item 467  of  505
# Item 468  of  505
# Item 469  of  505
# Item 470  of  505
# Item 471  of  505
# Item 472  of  505
# Item 473  of  505
# Item 474  of  505
# Item 475  of  505
# Item 476  of  505
# Item 477  of  505
# Item 478  of  505
# Item 479  of  505
# Item 480  of  505
# Item 481  of  505
# Item 482  of  505
# Item 483  of  505
# Item 484  of  505
# Item 485  of  505
# Item 486  of  505
# Item 487  of  505
# Item 488  of  505
# Item 489  of  505
# Item 490  of  505
# Item 491  of  505
# Item 492  of  505
# Item 493  of  505
# Item 494  of  505
# Item 495  of  505
# Item 496  of  505
# Item 497  of  505
# Item 498  of  505
# Item 499  of  505
# Item 500  of  505
# Item 501  of  505
# Item 502  of  505
# Item 503  of  505
# Item 504  of  505
# Item 505  of  505
# Completed sampling
# Completed predictions
# 1513 196
#  SVD complete
# Reduced the number of features from 196  to  138
# (1513, 138)
# (1513,)
# Performing hyper parameter search
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Plot_principal_features.py:50: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sactter_plot = sns.scatterplot(data=internal_dataframe, x='Reduced Feature 1', y = 'Reduced Feature 2', hue='Class Names', palette=palette, hue_order=reordered_names)
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [16] 0.9345670852610707
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [37, 37] 0.9933906146728354
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [51, 51] 0.9980171844018506
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [53, 53] 0.9993390614672836
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [44, 44] 0.9980171844018506
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [35] 0.9610046265697291
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [32, 32] 0.9933906146728354
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [49] 0.9563780568407139
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [46, 46] 0.9960343688037012
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [20, 20] 0.9808327825512227
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [37, 37] 0.9933906146728354
# [64, 64, 64] 1.0
# [54, 54, 54] 1.0
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [16, 16, 16] 0.9933906146728354
# [41, 41, 41] 1.0
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [64, 64] 0.9980171844018506
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [59, 59] 0.9993390614672836
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [29, 29, 29] 1.0
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [3, 64] before, using random point [3, 21]
#   warnings.warn(
# [64] 0.9524124256444151
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [21, 21, 21] 0.9993390614672836
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [3, 64] before, using random point [2, 61]
#   warnings.warn(
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [61, 61] 0.998678122934567
# [59, 59, 59] 1.0
# [47, 47, 47] 1.0
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [2, 59] before, using random point [2, 64]
#   warnings.warn(
# [34, 34, 34] 0.9993390614672836
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [64, 64] 0.9980171844018506
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [2, 58] before, using random point [2, 59]
#   warnings.warn(
# [58, 58] 0.9993390614672836
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [3, 64] before, using random point [3, 50]
#   warnings.warn(
# [59, 59] 0.9993390614672836
# [50, 50, 50] 1.0
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [3, 64] before, using random point [2, 51]
#   warnings.warn(
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [3, 64] before, using random point [2, 54]
#   warnings.warn(
# [51, 51] 0.9980171844018506
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [54, 54] 0.9993390614672836
# Found optimumum settings
# [3, 64]
# 0.0
# Item 1  of  505
# Completed posterior plots
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:166: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale("log")
#              Class  Post_prob
# 0    British Coins   0.000000
# 1    British Coins   0.000001
# 2    British Coins   0.000001
# 3    British Coins   0.000000
# 4    British Coins   0.000001
# ..             ...        ...
# 395   Screwdrivers   1.000000
# 396   Screwdrivers   1.000000
# 397   Screwdrivers   0.999999
# 398   Screwdrivers   0.999999
# 399   Screwdrivers   0.999999
#
# [400 rows x 2 columns]
# Item 2  of  505
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:265: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(data=df, x="Post_prob",y="Class",cut=0,scale="width")
# Completed posterior plots
#              Class     Post_prob
# 0    British Coins  7.724977e-02
# 1    British Coins  2.259959e-02
# 2    British Coins  7.534515e-02
# 3    British Coins  6.327330e-02
# 4    British Coins  1.304926e-01
# ..             ...           ...
# 395   Screwdrivers  4.149226e-08
# 396   Screwdrivers  1.504273e-06
# 397   Screwdrivers  2.503577e-08
# 398   Screwdrivers  1.952438e-08
# 399   Screwdrivers  2.508101e-06
#
# [400 rows x 2 columns]
# Item 3  of  505
# Item 4  of  505
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:265: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(data=df, x="Post_prob",y="Class",cut=0,scale="width")
# Completed posterior plots
#              Class     Post_prob
# 0    British Coins  3.585946e-01
# 1    British Coins  7.821006e-01
# 2    British Coins  5.559148e-01
# 3    British Coins  7.029331e-01
# 4    British Coins  3.856553e-01
# ..             ...           ...
# 395   Screwdrivers  2.290018e-03
# 396   Screwdrivers  8.598648e-05
# 397   Screwdrivers  7.412981e-08
# 398   Screwdrivers  7.897764e-06
# 399   Screwdrivers  5.682622e-05
#
# [400 rows x 2 columns]
# Item 5  of  505
# Item 6  of  505
# Item 7  of  505
# Item 8  of  505
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:265: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(data=df, x="Post_prob",y="Class",cut=0,scale="width")
# Item 9  of  505
# Item 10  of  505
# Item 11  of  505
# Item 12  of  505
# Item 13  of  505
# Item 14  of  505
# Item 15  of  505
# Item 16  of  505
# Completed posterior plots
#              Class     Post_prob
# 0    British Coins  0.000000e+00
# 1    British Coins  0.000000e+00
# 2    British Coins  0.000000e+00
# 3    British Coins  7.777374e-07
# 4    British Coins  8.807542e-07
# ..             ...           ...
# 395   Screwdrivers  0.000000e+00
# 396   Screwdrivers  0.000000e+00
# 397   Screwdrivers  0.000000e+00
# 398   Screwdrivers  0.000000e+00
# 399   Screwdrivers  0.000000e+00
#
# [400 rows x 2 columns]
# Item 17  of  505
# Item 18  of  505
# Item 19  of  505
# Item 20  of  505
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:265: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(data=df, x="Post_prob",y="Class",cut=0,scale="width")
# Item 21  of  505
# Item 22  of  505
# Item 23  of  505
# Item 24  of  505
# Item 25  of  505
# Item 26  of  505
# Item 27  of  505
# Item 28  of  505
# Item 29  of  505
# Item 30  of  505
# Item 31  of  505
# Item 32  of  505
# Item 33  of  505
# Item 34  of  505
# Item 35  of  505
# Item 36  of  505
# Item 37  of  505
# Item 38  of  505
# Item 39  of  505
# Item 40  of  505
# Item 41  of  505
# Item 42  of  505
# Item 43  of  505
# Item 44  of  505
# Item 45  of  505
# Item 46  of  505
# Item 47  of  505
# Item 48  of  505
# Item 49  of  505
# Item 50  of  505
# Item 51  of  505
# Item 52  of  505
# Item 53  of  505
# Item 54  of  505
# Item 55  of  505
# Item 56  of  505
# Item 57  of  505
# Item 58  of  505
# Item 59  of  505
# Item 60  of  505
# Item 61  of  505
# Item 62  of  505
# Item 63  of  505
# Item 64  of  505
# Item 65  of  505
# Item 66  of  505
# Item 67  of  505
# Item 68  of  505
# Item 69  of  505
# Item 70  of  505
# Item 71  of  505
# Item 72  of  505
# Item 73  of  505
# Item 74  of  505
# Item 75  of  505
# Item 76  of  505
# Item 77  of  505
# Item 78  of  505
# Item 79  of  505
# Item 80  of  505
# Item 81  of  505
# Item 82  of  505
# Item 83  of  505
# Item 84  of  505
# Item 85  of  505
# Item 86  of  505
# Item 87  of  505
# Item 88  of  505
# Item 89  of  505
# Item 90  of  505
# Item 91  of  505
# Item 92  of  505
# Item 93  of  505
# Item 94  of  505
# Item 95  of  505
# Item 96  of  505
# Item 97  of  505
# Item 98  of  505
# Item 99  of  505
# Item 100  of  505
# Item 101  of  505
# Item 102  of  505
# Item 103  of  505
# Item 104  of  505
# Item 105  of  505
# Item 106  of  505
# Item 107  of  505
# Item 108  of  505
# Item 109  of  505
# Item 110  of  505
# Item 111  of  505
# Item 112  of  505
# Item 113  of  505
# Item 114  of  505
# Item 115  of  505
# Item 116  of  505
# Item 117  of  505
# Item 118  of  505
# Item 119  of  505
# Item 120  of  505
# Item 121  of  505
# Item 122  of  505
# Item 123  of  505
# Item 124  of  505
# Item 125  of  505
# Item 126  of  505
# Item 127  of  505
# Item 128  of  505
# Item 129  of  505
# Item 130  of  505
# Item 131  of  505
# Item 132  of  505
# Item 133  of  505
# Item 134  of  505
# Item 135  of  505
# Item 136  of  505
# Item 137  of  505
# Item 138  of  505
# Item 139  of  505
# Item 140  of  505
# Item 141  of  505
# Item 142  of  505
# Item 143  of  505
# Item 144  of  505
# Item 145  of  505
# Item 146  of  505
# Item 147  of  505
# Item 148  of  505
# Item 149  of  505
# Item 150  of  505
# Item 151  of  505
# Item 152  of  505
# Item 153  of  505
# Item 154  of  505
# Item 155  of  505
# Item 156  of  505
# Item 157  of  505
# Item 158  of  505
# Item 159  of  505
# Item 160  of  505
# Item 161  of  505
# Item 162  of  505
# Item 163  of  505
# Item 164  of  505
# Item 165  of  505
# Item 166  of  505
# Item 167  of  505
# Item 168  of  505
# Item 169  of  505
# Item 170  of  505
# Item 171  of  505
# Item 172  of  505
# Item 173  of  505
# Item 174  of  505
# Item 175  of  505
# Item 176  of  505
# Item 177  of  505
# Item 178  of  505
# Item 179  of  505
# Item 180  of  505
# Item 181  of  505
# Item 182  of  505
# Item 183  of  505
# Item 184  of  505
# Item 185  of  505
# Item 186  of  505
# Item 187  of  505
# Item 188  of  505
# Item 189  of  505
# Item 190  of  505
# Item 191  of  505
# Item 192  of  505
# Item 193  of  505
# Item 194  of  505
# Item 195  of  505
# Item 196  of  505
# Item 197  of  505
# Item 198  of  505
# Item 199  of  505
# Item 200  of  505
# Item 201  of  505
# Item 202  of  505
# Item 203  of  505
# Item 204  of  505
# Item 205  of  505
# Item 206  of  505
# Item 207  of  505
# Item 208  of  505
# Item 209  of  505
# Item 210  of  505
# Item 211  of  505
# Item 212  of  505
# Item 213  of  505
# Item 214  of  505
# Item 215  of  505
# Item 216  of  505
# Item 217  of  505
# Item 218  of  505
# Item 219  of  505
# Item 220  of  505
# Item 221  of  505
# Item 222  of  505
# Item 223  of  505
# Item 224  of  505
# Item 225  of  505
# Item 226  of  505
# Item 227  of  505
# Item 228  of  505
# Item 229  of  505
# Item 230  of  505
# Item 231  of  505
# Item 232  of  505
# Item 233  of  505
# Item 234  of  505
# Item 235  of  505
# Item 236  of  505
# Item 237  of  505
# Item 238  of  505
# Item 239  of  505
# Item 240  of  505
# Item 241  of  505
# Item 242  of  505
# Item 243  of  505
# Item 244  of  505
# Item 245  of  505
# Item 246  of  505
# Item 247  of  505
# Item 248  of  505
# Item 249  of  505
# Item 250  of  505
# Item 251  of  505
# Item 252  of  505
# Item 253  of  505
# Item 254  of  505
# Item 255  of  505
# Item 256  of  505
# Item 257  of  505
# Item 258  of  505
# Item 259  of  505
# Item 260  of  505
# Item 261  of  505
# Item 262  of  505
# Item 263  of  505
# Item 264  of  505
# Item 265  of  505
# Item 266  of  505
# Item 267  of  505
# Item 268  of  505
# Item 269  of  505
# Item 270  of  505
# Item 271  of  505
# Item 272  of  505
# Item 273  of  505
# Item 274  of  505
# Item 275  of  505
# Item 276  of  505
# Item 277  of  505
# Item 278  of  505
# Item 279  of  505
# Item 280  of  505
# Item 281  of  505
# Item 282  of  505
# Item 283  of  505
# Item 284  of  505
# Item 285  of  505
# Item 286  of  505
# Item 287  of  505
# Item 288  of  505
# Item 289  of  505
# Item 290  of  505
# Item 291  of  505
# Item 292  of  505
# Item 293  of  505
# Item 294  of  505
# Item 295  of  505
# Item 296  of  505
# Item 297  of  505
# Item 298  of  505
# Item 299  of  505
# Item 300  of  505
# Item 301  of  505
# Item 302  of  505
# Item 303  of  505
# Item 304  of  505
# Item 305  of  505
# Item 306  of  505
# Item 307  of  505
# Item 308  of  505
# Item 309  of  505
# Item 310  of  505
# Item 311  of  505
# Item 312  of  505
# Item 313  of  505
# Item 314  of  505
# Item 315  of  505
# Item 316  of  505
# Item 317  of  505
# Item 318  of  505
# Item 319  of  505
# Item 320  of  505
# Item 321  of  505
# Item 322  of  505
# Item 323  of  505
# Item 324  of  505
# Item 325  of  505
# Item 326  of  505
# Item 327  of  505
# Item 328  of  505
# Item 329  of  505
# Item 330  of  505
# Item 331  of  505
# Item 332  of  505
# Item 333  of  505
# Item 334  of  505
# Item 335  of  505
# Item 336  of  505
# Item 337  of  505
# Item 338  of  505
# Item 339  of  505
# Item 340  of  505
# Item 341  of  505
# Item 342  of  505
# Item 343  of  505
# Item 344  of  505
# Item 345  of  505
# Item 346  of  505
# Item 347  of  505
# Item 348  of  505
# Item 349  of  505
# Item 350  of  505
# Item 351  of  505
# Item 352  of  505
# Item 353  of  505
# Item 354  of  505
# Item 355  of  505
# Item 356  of  505
# Item 357  of  505
# Item 358  of  505
# Item 359  of  505
# Item 360  of  505
# Item 361  of  505
# Item 362  of  505
# Item 363  of  505
# Item 364  of  505
# Item 365  of  505
# Item 366  of  505
# Item 367  of  505
# Item 368  of  505
# Item 369  of  505
# Item 370  of  505
# Item 371  of  505
# Item 372  of  505
# Item 373  of  505
# Item 374  of  505
# Item 375  of  505
# Item 376  of  505
# Item 377  of  505
# Item 378  of  505
# Item 379  of  505
# Item 380  of  505
# Item 381  of  505
# Item 382  of  505
# Item 383  of  505
# Item 384  of  505
# Item 385  of  505
# Item 386  of  505
# Item 387  of  505
# Item 388  of  505
# Item 389  of  505
# Item 390  of  505
# Item 391  of  505
# Item 392  of  505
# Item 393  of  505
# Item 394  of  505
# Item 395  of  505
# Item 396  of  505
# Item 397  of  505
# Item 398  of  505
# Item 399  of  505
# Item 400  of  505
# Item 401  of  505
# Item 402  of  505
# Item 403  of  505
# Item 404  of  505
# Item 405  of  505
# Item 406  of  505
# Item 407  of  505
# Item 408  of  505
# Item 409  of  505
# Item 410  of  505
# Item 411  of  505
# Item 412  of  505
# Item 413  of  505
# Item 414  of  505
# Item 415  of  505
# Item 416  of  505
# Item 417  of  505
# Item 418  of  505
# Item 419  of  505
# Item 420  of  505
# Item 421  of  505
# Item 422  of  505
# Item 423  of  505
# Item 424  of  505
# Item 425  of  505
# Item 426  of  505
# Item 427  of  505
# Item 428  of  505
# Item 429  of  505
# Item 430  of  505
# Item 431  of  505
# Item 432  of  505
# Item 433  of  505
# Item 434  of  505
# Item 435  of  505
# Item 436  of  505
# Item 437  of  505
# Item 438  of  505
# Item 439  of  505
# Item 440  of  505
# Item 441  of  505
# Item 442  of  505
# Item 443  of  505
# Item 444  of  505
# Item 445  of  505
# Item 446  of  505
# Item 447  of  505
# Item 448  of  505
# Item 449  of  505
# Item 450  of  505
# Item 451  of  505
# Item 452  of  505
# Item 453  of  505
# Item 454  of  505
# Item 455  of  505
# Item 456  of  505
# Item 457  of  505
# Item 458  of  505
# Item 459  of  505
# Item 460  of  505
# Item 461  of  505
# Item 462  of  505
# Item 463  of  505
# Item 464  of  505
# Item 465  of  505
# Item 466  of  505
# Item 467  of  505
# Item 468  of  505
# Item 469  of  505
# Item 470  of  505
# Item 471  of  505
# Item 472  of  505
# Item 473  of  505
# Item 474  of  505
# Item 475  of  505
# Item 476  of  505
# Item 477  of  505
# Item 478  of  505
# Item 479  of  505
# Item 480  of  505
# Item 481  of  505
# Item 482  of  505
# Item 483  of  505
# Item 484  of  505
# Item 485  of  505
# Item 486  of  505
# Item 487  of  505
# Item 488  of  505
# Item 489  of  505
# Item 490  of  505
# Item 491  of  505
# Item 492  of  505
# Item 493  of  505
# Item 494  of  505
# Item 495  of  505
# Item 496  of  505
# Item 497  of  505
# Item 498  of  505
# Item 499  of  505
# Item 500  of  505
# Item 501  of  505
# Item 502  of  505
# Item 503  of  505
# Item 504  of  505
# Item 505  of  505
# Completed sampling
# Completed predictions
# 1513 196
#  SVD complete
# Reduced the number of features from 196  to  138
# (1513, 138)
# (1513,)
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Plot_principal_features.py:50: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sactter_plot = sns.scatterplot(data=internal_dataframe, x='Reduced Feature 1', y = 'Reduced Feature 2', hue='Class Names', palette=palette, hue_order=reordered_names)
# Performing hyper parameter search
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [16] 0.9345670852610707
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [37, 37] 0.9933906146728354
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [51, 51] 0.9980171844018506
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [53, 53] 0.9993390614672836
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [44, 44] 0.9980171844018506
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [35] 0.9610046265697291
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [32, 32] 0.9933906146728354
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [49] 0.9563780568407139
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [46, 46] 0.9960343688037012
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [20, 20] 0.9808327825512227
# ...
# Item 435  of  505
# Item 436  of  505
# Item 437  of  505
# Item 438  of  505
# Item 439  of  505
# Item 440  of  505
# Item 441  of  505
# Item 442  of  505
# Item 443  of  505
# Item 444  of  505
# Item 445  of  505
# Item 446  of  505
# Item 447  of  505
# Item 448  of  505
# Item 449  of  505
# Item 450  of  505
# Item 451  of  505
# Item 452  of  505
# Item 453  of  505
# Item 454  of  505
# Item 455  of  505
# Item 456  of  505
# Item 457  of  505
# Item 458  of  505
# Item 459  of  505
# Item 460  of  505
# Item 461  of  505
# Item 462  of  505
# Item 463  of  505
# Item 464  of  505
# Item 465  of  505
# Item 466  of  505
# Item 467  of  505
# Item 468  of  505
# Item 469  of  505
# Item 470  of  505
# Item 471  of  505
# Item 472  of  505
# Item 473  of  505
# Item 474  of  505
# Item 475  of  505
# Item 476  of  505
# Item 477  of  505
# Item 478  of  505
# Item 479  of  505
# Item 480  of  505
# Item 481  of  505
# Item 482  of  505
# Item 483  of  505
# Item 484  of  505
# Item 485  of  505
# Item 486  of  505
# Item 487  of  505
# Item 488  of  505
# Item 489  of  505
# Item 490  of  505
# Item 491  of  505
# Item 492  of  505
# Item 493  of  505
# Item 494  of  505
# Item 495  of  505
# Item 496  of  505
# Item 497  of  505
# Item 498  of  505
# Item 499  of  505
# Item 500  of  505
# Item 501  of  505
# Item 502  of  505
# Item 503  of  505
# Item 504  of  505
# Item 505  of  505
# Completed sampling
# Completed predictions
# 1513 196
#  SVD complete
# Reduced the number of features from 196  to  107
# (1513, 107)
# (1513,)
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Plot_principal_features.py:50: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sactter_plot = sns.scatterplot(data=internal_dataframe, x='Reduced Feature 1', y = 'Reduced Feature 2', hue='Class Names', palette=palette, hue_order=reordered_names)
# Performing hyper parameter search
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [16] 0.9960343688037012
# [37, 37] 1.0
# [51, 51] 1.0
# [53, 53] 1.0
# [44, 44] 1.0
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [35] 1.0
# [32, 32] 1.0
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [49] 1.0
# [46, 46] 1.0
# [20, 20] 1.0
# [37, 37] 1.0
# [55, 55, 55] 1.0
# [16, 16, 16] 1.0
# [35, 35, 35] 1.0
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [64] 1.0
# [64, 64, 64] 1.0
# [64, 64] 1.0
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [41] 1.0
# [25, 25, 25] 1.0
# [61, 61, 61] 1.0
# [26, 26, 26] 1.0
# [60, 60, 60] 1.0
# [31, 31] 1.0
# /home/paul/anaconda3/envs/classification/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [57] 1.0
# [38, 38] 1.0
# [60, 60] 1.0
# [21, 21] 1.0
# [31, 31, 31] 1.0
# [45, 45, 45] 1.0
# [16, 16] 1.0
# Found optimumum settings
# [2, 37]
# 0.0
# Item 1  of  505
# Completed posterior plots
#              Class  Post_prob
# 0    British Coins   0.941743
# 1    British Coins   0.848254
# 2    British Coins   0.996722
# 3    British Coins   0.987027
# 4    British Coins   0.917286
# ..             ...        ...
# 395   Screwdrivers   0.000025
# 396   Screwdrivers   0.000058
# 397   Screwdrivers   0.000131
# 398   Screwdrivers   0.000260
# 399   Screwdrivers   0.000115
#
# [400 rows x 2 columns]
# Item 2  of  505
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:265: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(data=df, x="Post_prob",y="Class",cut=0,scale="width")
# Completed posterior plots
#              Class     Post_prob
# 0    British Coins  1.755282e-03
# 1    British Coins  1.990549e-02
# 2    British Coins  3.046486e-03
# 3    British Coins  2.102793e-02
# 4    British Coins  1.378736e-03
# ..             ...           ...
# 395   Screwdrivers  2.240340e-07
# 396   Screwdrivers  1.847551e-08
# 397   Screwdrivers  1.360782e-08
# 398   Screwdrivers  6.977546e-06
# 399   Screwdrivers  3.409046e-08
#
# [400 rows x 2 columns]
# Item 3  of  505
# Item 4  of  505
# Item 5  of  505
# Item 6  of  505
# Item 7  of  505
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:265: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(data=df, x="Post_prob",y="Class",cut=0,scale="width")
# Item 8  of  505
# Item 9  of  505
# Completed posterior plots
#              Class     Post_prob
# 0    British Coins  9.783084e-08
# 1    British Coins  0.000000e+00
# 2    British Coins  1.252707e-06
# 3    British Coins  1.015930e-07
# 4    British Coins  0.000000e+00
# ..             ...           ...
# 395   Screwdrivers  1.000000e+00
# 396   Screwdrivers  1.000000e+00
# 397   Screwdrivers  1.000000e+00
# 398   Screwdrivers  9.999998e-01
# 399   Screwdrivers  1.000000e+00
#
# [400 rows x 2 columns]
# Item 10  of  505
# Item 11  of  505
# Item 12  of  505
# Item 13  of  505
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:265: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(data=df, x="Post_prob",y="Class",cut=0,scale="width")
# Completed posterior plots
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:166: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale("log")
#              Class     Post_prob
# 0    British Coins  3.268325e-07
# 1    British Coins  0.000000e+00
# 2    British Coins  1.135861e-06
# 3    British Coins  0.000000e+00
# 4    British Coins  3.705658e-07
# ..             ...           ...
# 395   Screwdrivers  0.000000e+00
# 396   Screwdrivers  6.141302e-07
# 397   Screwdrivers  0.000000e+00
# 398   Screwdrivers  0.000000e+00
# 399   Screwdrivers  0.000000e+00
#
# [400 rows x 2 columns]
# Item 14  of  505
# Item 15  of  505
# Item 16  of  505
# Item 17  of  505
# Item 18  of  505
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:265: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(data=df, x="Post_prob",y="Class",cut=0,scale="width")
# Item 19  of  505
# Item 20  of  505
# Item 21  of  505
# Item 22  of  505
# Item 23  of  505
# Item 24  of  505
# Item 25  of  505
# Item 26  of  505
# Item 27  of  505
# Item 28  of  505
# Item 29  of  505
# Item 30  of  505
# Item 31  of  505
# Item 32  of  505
# Item 33  of  505
# Item 34  of  505
# Item 35  of  505
# Item 36  of  505
# Item 37  of  505
# Item 38  of  505
# Item 39  of  505
# Item 40  of  505
# Item 41  of  505
# Item 42  of  505
# Item 43  of  505
# Item 44  of  505
# Item 45  of  505
# Item 46  of  505
# Item 47  of  505
# Item 48  of  505
# Item 49  of  505
# Item 50  of  505
# Item 51  of  505
# Item 52  of  505
# Item 53  of  505
# Item 54  of  505
# Item 55  of  505
# Item 56  of  505
# Item 57  of  505
# Item 58  of  505
# Item 59  of  505
# Item 60  of  505
# Item 61  of  505
# Item 62  of  505
# Item 63  of  505
# Item 64  of  505
# Item 65  of  505
# Item 66  of  505
# Item 67  of  505
# Item 68  of  505
# Item 69  of  505
# Item 70  of  505
# Item 71  of  505
# Item 72  of  505
# Item 73  of  505
# Item 74  of  505
# Item 75  of  505
# Item 76  of  505
# Item 77  of  505
# Item 78  of  505
# Item 79  of  505
# Item 80  of  505
# Item 81  of  505
# Item 82  of  505
# Item 83  of  505
# Item 84  of  505
# Item 85  of  505
# Item 86  of  505
# Item 87  of  505
# Item 88  of  505
# Item 89  of  505
# Item 90  of  505
# Item 91  of  505
# Item 92  of  505
# Item 93  of  505
# Item 94  of  505
# Item 95  of  505
# Item 96  of  505
# Item 97  of  505
# Item 98  of  505
# Item 99  of  505
# Item 100  of  505
# Item 101  of  505
# Item 102  of  505
# Item 103  of  505
# Item 104  of  505
# Item 105  of  505
# Item 106  of  505
# Item 107  of  505
# Item 108  of  505
# Item 109  of  505
# Item 110  of  505
# Item 111  of  505
# Item 112  of  505
# Item 113  of  505
# Item 114  of  505
# Item 115  of  505
# Item 116  of  505
# Item 117  of  505
# Item 118  of  505
# Item 119  of  505
# Item 120  of  505
# Item 121  of  505
# Item 122  of  505
# Item 123  of  505
# Item 124  of  505
# Item 125  of  505
# Item 126  of  505
# Item 127  of  505
# Item 128  of  505
# Item 129  of  505
# Item 130  of  505
# Item 131  of  505
# Item 132  of  505
# Item 133  of  505
# Item 134  of  505
# Item 135  of  505
# Item 136  of  505
# Item 137  of  505
# Item 138  of  505
# Item 139  of  505
# Item 140  of  505
# Item 141  of  505
# Item 142  of  505
# Item 143  of  505
# Item 144  of  505
# Item 145  of  505
# Item 146  of  505
# Item 147  of  505
# Item 148  of  505
# Item 149  of  505
# Item 150  of  505
# Item 151  of  505
# Item 152  of  505
# Item 153  of  505
# Item 154  of  505
# Item 155  of  505
# Item 156  of  505
# Item 157  of  505
# Item 158  of  505
# Item 159  of  505
# Item 160  of  505
# Item 161  of  505
# Item 162  of  505
# Item 163  of  505
# Item 164  of  505
# Item 165  of  505
# Item 166  of  505
# Item 167  of  505
# Item 168  of  505
# Item 169  of  505
# Item 170  of  505
# Item 171  of  505
# Item 172  of  505
# Item 173  of  505
# Item 174  of  505
# Item 175  of  505
# Item 176  of  505
# Item 177  of  505
# Item 178  of  505
# Item 179  of  505
# Item 180  of  505
# Item 181  of  505
# Item 182  of  505
# Item 183  of  505
# Item 184  of  505
# Item 185  of  505
# Item 186  of  505
# Item 187  of  505
# Item 188  of  505
# Item 189  of  505
# Item 190  of  505
# Item 191  of  505
# Item 192  of  505
# Item 193  of  505
# Item 194  of  505
# Item 195  of  505
# Item 196  of  505
# Item 197  of  505
# Item 198  of  505
# Item 199  of  505
# Item 200  of  505
# Item 201  of  505
# Item 202  of  505
# Item 203  of  505
# Item 204  of  505
# Item 205  of  505
# Item 206  of  505
# Item 207  of  505
# Item 208  of  505
# Item 209  of  505
# Item 210  of  505
# Item 211  of  505
# Item 212  of  505
# Item 213  of  505
# Item 214  of  505
# Item 215  of  505
# Item 216  of  505
# Item 217  of  505
# Item 218  of  505
# Item 219  of  505
# Item 220  of  505
# Item 221  of  505
# Item 222  of  505
# Item 223  of  505
# Item 224  of  505
# Item 225  of  505
# Item 226  of  505
# Item 227  of  505
# Item 228  of  505
# Item 229  of  505
# Item 230  of  505
# Item 231  of  505
# Item 232  of  505
# Item 233  of  505
# Item 234  of  505
# Item 235  of  505
# Item 236  of  505
# Item 237  of  505
# Item 238  of  505
# Item 239  of  505
# Item 240  of  505
# Item 241  of  505
# Item 242  of  505
# Item 243  of  505
# Item 244  of  505
# Item 245  of  505
# Item 246  of  505
# Item 247  of  505
# Item 248  of  505
# Item 249  of  505
# Item 250  of  505
# Item 251  of  505
# Item 252  of  505
# Item 253  of  505
# Item 254  of  505
# Item 255  of  505
# Item 256  of  505
# Item 257  of  505
# Item 258  of  505
# Item 259  of  505
# Item 260  of  505
# Item 261  of  505
# Item 262  of  505
# Item 263  of  505
# Item 264  of  505
# Item 265  of  505
# Item 266  of  505
# Item 267  of  505
# Item 268  of  505
# Item 269  of  505
# Item 270  of  505
# Item 271  of  505
# Item 272  of  505
# Item 273  of  505
# Item 274  of  505
# Item 275  of  505
# Item 276  of  505
# Item 277  of  505
# Item 278  of  505
# Item 279  of  505
# Item 280  of  505
# Item 281  of  505
# Item 282  of  505
# Item 283  of  505
# Item 284  of  505
# Item 285  of  505
# Item 286  of  505
# Item 287  of  505
# Item 288  of  505
# Item 289  of  505
# Item 290  of  505
# Item 291  of  505
# Item 292  of  505
# Item 293  of  505
# Item 294  of  505
# Item 295  of  505
# Item 296  of  505
# Item 297  of  505
# Item 298  of  505
# Item 299  of  505
# Item 300  of  505
# Item 301  of  505
# Item 302  of  505
# Item 303  of  505
# Item 304  of  505
# Item 305  of  505
# Item 306  of  505
# Item 307  of  505
# Item 308  of  505
# Item 309  of  505
# Item 310  of  505
# Item 311  of  505
# Item 312  of  505
# Item 313  of  505
# Item 314  of  505
# Item 315  of  505
# Item 316  of  505
# Item 317  of  505
# Item 318  of  505
# Item 319  of  505
# Item 320  of  505
# Item 321  of  505
# Item 322  of  505
# Item 323  of  505
# Item 324  of  505
# Item 325  of  505
# Item 326  of  505
# Item 327  of  505
# Item 328  of  505
# Item 329  of  505
# Item 330  of  505
# Item 331  of  505
# Item 332  of  505
# Item 333  of  505
# Item 334  of  505
# Item 335  of  505
# Item 336  of  505
# Item 337  of  505
# Item 338  of  505
# Item 339  of  505
# Item 340  of  505
# Item 341  of  505
# Item 342  of  505
# Item 343  of  505
# Item 344  of  505
# Item 345  of  505
# Item 346  of  505
# Item 347  of  505
# Item 348  of  505
# Item 349  of  505
# Item 350  of  505
# Item 351  of  505
# Item 352  of  505
# Item 353  of  505
# Item 354  of  505
# Item 355  of  505
# Item 356  of  505
# Item 357  of  505
# Item 358  of  505
# Item 359  of  505
# Item 360  of  505
# Item 361  of  505
# Item 362  of  505
# Item 363  of  505
# Item 364  of  505
# Item 365  of  505
# Item 366  of  505
# Item 367  of  505
# Item 368  of  505
# Item 369  of  505
# Item 370  of  505
# Item 371  of  505
# Item 372  of  505
# Item 373  of  505
# Item 374  of  505
# Item 375  of  505
# Item 376  of  505
# Item 377  of  505
# Item 378  of  505
# Item 379  of  505
# Item 380  of  505
# Item 381  of  505
# Item 382  of  505
# Item 383  of  505
# Item 384  of  505
# Item 385  of  505
# Item 386  of  505
# Item 387  of  505
# Item 388  of  505
# Item 389  of  505
# Item 390  of  505
# Item 391  of  505
# Item 392  of  505
# Item 393  of  505
# Item 394  of  505
# Item 395  of  505
# Item 396  of  505
# Item 397  of  505
# Item 398  of  505
# Item 399  of  505
# Item 400  of  505
# Item 401  of  505
# Item 402  of  505
# Item 403  of  505
# Item 404  of  505
# Item 405  of  505
# Item 406  of  505
# Item 407  of  505
# Item 408  of  505
# Item 409  of  505
# Item 410  of  505
# Item 411  of  505
# Item 412  of  505
# Item 413  of  505
# Item 414  of  505
# Item 415  of  505
# Item 416  of  505
# Item 417  of  505
# Item 418  of  505
# Item 419  of  505
# Item 420  of  505
# Item 421  of  505
# Item 422  of  505
# Item 423  of  505
# Item 424  of  505
# Item 425  of  505
# Item 426  of  505
# Item 427  of  505
# Item 428  of  505
# Item 429  of  505
# Item 430  of  505
# Item 431  of  505
# Item 432  of  505
# Item 433  of  505
# Item 434  of  505
# Item 435  of  505
# Item 436  of  505
# Item 437  of  505
# Item 438  of  505
# Item 439  of  505
# Item 440  of  505
# Item 441  of  505
# Item 442  of  505
# Item 443  of  505
# Item 444  of  505
# Item 445  of  505
# Item 446  of  505
# Item 447  of  505
# Item 448  of  505
# Item 449  of  505
# Item 450  of  505
# Item 451  of  505
# Item 452  of  505
# Item 453  of  505
# Item 454  of  505
# Item 455  of  505
# Item 456  of  505
# Item 457  of  505
# Item 458  of  505
# Item 459  of  505
# Item 460  of  505
# Item 461  of  505
# Item 462  of  505
# Item 463  of  505
# Item 464  of  505
# Item 465  of  505
# Item 466  of  505
# Item 467  of  505
# Item 468  of  505
# Item 469  of  505
# Item 470  of  505
# Item 471  of  505
# Item 472  of  505
# Item 473  of  505
# Item 474  of  505
# Item 475  of  505
# Item 476  of  505
# Item 477  of  505
# Item 478  of  505
# Item 479  of  505
# Item 480  of  505
# Item 481  of  505
# Item 482  of  505
# Item 483  of  505
# Item 484  of  505
# Item 485  of  505
# Item 486  of  505
# Item 487  of  505
# Item 488  of  505
# Item 489  of  505
# Item 490  of  505
# Item 491  of  505
# Item 492  of  505
# Item 493  of  505
# Item 494  of  505
# Item 495  of  505
# Item 496  of  505
# Item 497  of  505
# Item 498  of  505
# Item 499  of  505
# Item 500  of  505
# Item 501  of  505
# Item 502  of  505
# Item 503  of  505
# Item 504  of  505
# Item 505  of  505
# Completed sampling
# Completed predictions
