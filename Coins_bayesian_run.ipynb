# %% [markdown]
# **The first thing to do is to run Creator.py to setup the dataset. First specify the options**

# %%
import numpy as np
# The Name of the Dataset
Name = "British-Coins-Updated-1p-2p-James/Coins-100"

# Frequency Array
Frequencies=np.array([119.25,178.875,238.5,298.125,357.75,477,596.25,715.5,954,1192.5,1431,1908,2385,2862,3816,4770,5724,7632,9540,12402,16218,20988,26712,34344,43884,57240,73458,95400])
Frequencies = Frequencies*6.28 #Convert to rad/s'

# Classes to Include
Classes = ["British_Coins_Updated_1p_2p"]

# Global number of results
# Coin Problem
extend_results = 'global_obj'

# Number of secondary results if 'global_obj'

#Coin Problem`
Num_Results = 100

# Classes if 'global_class' or 'classwise'
class_split=[]

# Name each of the classes this is done in order
class_names = []

# Number of results if 'global_class'
Num_Results_class = []


# (int) Number of results per class results per class if 'classwise'
class_num_results = []

#Labeler False,'Classwise', 'Objectwise'
Label_Data = 'Objectwise'
Name_Objects = True

#(dictionary) name the objects as you wish them to appear in the classificaiton
Object_Names_dictionary ={"Two_Pound":r"£2", "Ten_Pence":r"10p_(new)", "Ten_Pence_non_magnetic":r"10p_(old)", "One_Pound":r"£1", "Two_Penny":r"2p_(new)",
                              "Two_Penny_non_magnetic":r"2p_(old)", "Twenty_Pence":r"20p", "Five_Pence":r"5p_(new)", "Five_Pence_non_magnetic":r"5p_(old)",
                              "Fifty_Pence":r"50p", "One_Penny":r"1p_(new)", "One_Penny_non_magnetic":r"1p_(old)"}


Name_Order = ["One_Penny","One_Penny_non_magnetic","Two_Penny","Two_Penny_non_magnetic","Five_Pence","Five_Pence_non_magnetic",
             "Ten_Pence","Ten_Pence_non_magnetic","Twenty_Pence","Fifty_Pence","One_Pound","Two_Pound"]

#How to scale
Scale_type = 'Global'

#Which file (This is not currently used)
Scale_File = 'Coin_DataSet.csv'


#Alpha scale
Alpha_scale = 0.84

#Sigma scale
Sigma_scale = 12.5

# Path Name for where the class data is stored
Class_dir = "Classes_James"

# Create a dictionary of these settings
Creator_Settings = {"Name":Name,"Frequencies":Frequencies,"Classes":Classes,"extend_results":extend_results,"Num_Results":Num_Results,#
                    "class_split":class_split,"class_names":class_names,"Num_Results_class":Num_Results_class,"class_num_results":class_num_results,\
                    "Label_Data":Label_Data,"Name_Objects":Name_Objects,"Object_Names_dictionary":Object_Names_dictionary,"Name_Order":Name_Order,\
                    "Scale_type":Scale_type,"Scale_File":Scale_File,"Alpha_scale":Alpha_scale,"Sigma_scale":Sigma_scale,"Class_dir":Class_dir}

# %%
# Run the Creator script
from Creator import *
DataSet_Name=Creator(Creator_Settings)
# Out:
# The folder path to the dataset is: British-Coins-Updated-1p-2p-James/Coins-100_Al_0.84_Sig_12.5
# Class type is a list
# Five_Pence_non_magnetic
# One_Pound
# Two_Penny
# Two_Penny_non_magnetic
# Two_Pound
# Five_Pence
# One_Penny_non_magnetic
# Ten_Pence_non_magnetic
# Twenty_Pence
# Ten_Pence
# Fifty_Pence
# One_Penny
# (1200, 28) 28

# %%
# This is the dataset name to be used with the classifier
print(DataSet_Name)
# Out:
# British-Coins-Updated-1p-2p-James/Coins-100_Al_0.84_Sig_12.5

# %% [markdown]
# **The next part involves running the actual classifier. This is done using Trainer_PDL.py**

# %%
# Option to load external testing data from disk. Requires that external_file_loader.py be run first.
Load_External_Data = False 
# Option to plot comparison figures between the input array of simulated data and the external test data.
# Currently only supported for a single class test set.
Plot_Comparison_Figures = False
# Option to additionally save to disk: the model for each bootstrap iteration, the normalisation coefficients for each,
# bootstrap iteration, and the input array for each model, Used for debugging.
Full_Save = False

# Option to use SVD to reduce the number of features
Reduce_Features = True

#Model to be used
#Optional models 'LogisticRegression', 'SVM', 'DecisionTree', 'RandomForest', 'GradientBoost', 'MLP','MLP,(n1,n2,...,nn)'
#Models_to_run = ['LogisticRegression','SVM','GradientBoost']
Models_to_run = ["LogisticRegression_Bayesian"]


#Features
Features = ['Pri1', 'Pri2', 'Pri3']#,'AngleRtildeI']
# Features = ['Eig1', 'Eig2', 'Eig3']
#(list) list of features to be used options:
#'Eig1','Eig2','Eig3','Pri1','Pri2','Pri3','Dev2','Dev3','Com'
#Eigenvalues, Principal invarients, Deviatoric invarients, Comutator

#How many times would you like to train the model
Bootstrap_Repetitions = 1
#(int) how many times to train the model to obtain an average accuracy

# use default levels of SNR
SNR_array=[]

# Make plot of first two reduced invairants
Plot_Principal_Componenets = True

Trainer_Settings = {"DataSet_Name": DataSet_Name, "Load_External_Data":Load_External_Data, "Plot_Comparison_Figures":Plot_Comparison_Figures,\
                   "Full_Save": Full_Save, "Reduce_Features":Reduce_Features, "Models_to_run": Models_to_run,\
                    "Features":Features, "Bootstrap_Repetitions": Bootstrap_Repetitions, "SNR_array": SNR_array, "Plot_Principal_Componenets":Plot_Principal_Componenets }

# %%
from Trainer_PDL import *

main(Trainer_Settings)
# Out:
# Noise level =  5
# (1200, 504)
# (1200, 170) (1200, 168)
# Data [[-7.25113214e-11 -1.63141836e-10 -2.90010239e-10 ...  4.14401578e-08
#    7.94693910e-08  1.35649943e-07]
#  [-7.25113214e-11 -1.63141836e-10 -2.90010239e-10 ...  7.27387811e-08
#    7.59203833e-08  7.86154184e-08]
#  [-7.25113214e-11 -1.63141836e-10 -2.90010239e-10 ...  4.12240569e-08
#    9.94329370e-08  9.31426014e-08]
#  ...
#  [ 5.78392560e-07  5.68245963e-07  5.56157557e-07 ...  4.32385960e-04
#    5.53687911e-04  6.15383704e-04]
#  [ 5.78392560e-07  5.68245963e-07  5.56157557e-07 ...  4.80999346e-04
#    5.78544549e-04  6.25623024e-04]
#  [ 5.78392560e-07  5.68245963e-07  5.56157557e-07 ...  4.39360202e-04
#    5.57306814e-04  6.16939174e-04]]
# to here
# LogisticRegression_Bayesian
# 900 168
#  SVD complete
# Reduced the number of features from 168  to  108
# (900, 108)
# (900,)
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Plot_principal_features.py:50: UserWarning:
# The palette list has fewer values (10) than needed (12) and will cycle, which may produce an uninterpretable plot.
#   sactter_plot = sns.scatterplot(data=internal_dataframe, x='Reduced Feature 1', y = 'Reduced Feature 2', hue='Class Names', palette=palette, hue_order=reordered_names)
# Item 1  of  300
# Completed posterior plots
#          Class  Post_prob
# 0     1p (new)   0.034867
# 1     1p (new)   0.034825
# 2     1p (new)   0.058466
# 3     1p (new)   0.095107
# 4     1p (new)   0.049557
# ...        ...        ...
# 1195        £2   0.001528
# 1196        £2   0.000042
# 1197        £2   0.000531
# 1198        £2   0.000316
# 1199        £2   0.000020
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 2  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  1.380395e-07
# 1     1p (new)  2.950174e-04
# 2     1p (new)  1.105858e-06
# 3     1p (new)  7.515081e-05
# 4     1p (new)  2.698159e-06
# ...        ...           ...
# 1195        £2  1.170114e-01
# 1196        £2  8.497410e-02
# 1197        £2  2.284928e-03
# 1198        £2  1.535167e-03
# 1199        £2  8.020735e-01
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 3  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  7.442335e-12
# 1     1p (new)  3.870382e-08
# 2     1p (new)  9.230347e-10
# 3     1p (new)  2.758608e-08
# 4     1p (new)  3.002336e-10
# ...        ...           ...
# 1195        £2  4.979414e-08
# 1196        £2  5.165034e-05
# 1197        £2  3.592574e-05
# 1198        £2  4.345281e-06
# 1199        £2  2.868899e-01
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 4  of  300
# Completed posterior plots
#          Class  Post_prob
# 0     1p (new)   0.002319
# 1     1p (new)   0.038483
# 2     1p (new)   0.023986
# 3     1p (new)   0.006129
# 4     1p (new)   0.047291
# ...        ...        ...
# 1195        £2   0.005193
# 1196        £2   0.001520
# 1197        £2   0.003210
# 1198        £2   0.000259
# 1199        £2   0.006279
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 5  of  300
# Completed posterior plots
#          Class  Post_prob
# 0     1p (new)   0.005743
# 1     1p (new)   0.005468
# 2     1p (new)   0.015870
# 3     1p (new)   0.008471
# 4     1p (new)   0.003304
# ...        ...        ...
# 1195        £2   0.000217
# 1196        £2   0.000017
# 1197        £2   0.000392
# 1198        £2   0.000116
# 1199        £2   0.000124
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 6  of  300
# Completed posterior plots
#          Class  Post_prob
# 0     1p (new)   0.001361
# 1     1p (new)   0.000102
# 2     1p (new)   0.002434
# 3     1p (new)   0.000189
# 4     1p (new)   0.000072
# ...        ...        ...
# 1195        £2   0.000066
# 1196        £2   0.000163
# 1197        £2   0.004783
# 1198        £2   0.000084
# 1199        £2   0.001512
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 7  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  3.589255e-03
# 1     1p (new)  1.020178e-03
# 2     1p (new)  1.997384e-03
# 3     1p (new)  1.933762e-03
# 4     1p (new)  7.155498e-04
# ...        ...           ...
# 1195        £2  2.074337e-06
# 1196        £2  1.662044e-04
# 1197        £2  6.601406e-05
# 1198        £2  5.232357e-07
# 1199        £2  1.082512e-05
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 8  of  300
# Completed posterior plots
#          Class  Post_prob
# 0     1p (new)   0.383241
# 1     1p (new)   0.148288
# 2     1p (new)   0.057932
# 3     1p (new)   0.000129
# 4     1p (new)   0.733303
# ...        ...        ...
# 1195        £2   0.004918
# 1196        £2   0.000015
# 1197        £2   0.000004
# 1198        £2   0.000150
# 1199        £2   0.001929
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 9  of  300
# Item 10  of  300
# Item 11  of  300
# Item 12  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  5.511033e-07
# 1     1p (new)  2.398596e-06
# 2     1p (new)  1.062393e-05
# 3     1p (new)  4.445696e-06
# 4     1p (new)  8.606884e-07
# ...        ...           ...
# 1195        £2  9.934704e-01
# 1196        £2  7.174030e-01
# 1197        £2  8.231300e-01
# 1198        £2  9.776831e-01
# 1199        £2  9.895710e-01
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 13  of  300
# Item 14  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  3.978903e-04
# 1     1p (new)  2.589956e-04
# 2     1p (new)  1.893572e-03
# 3     1p (new)  8.153219e-05
# 4     1p (new)  1.939676e-04
# ...        ...           ...
# 1195        £2  9.560418e-07
# 1196        £2  7.680642e-07
# 1197        £2  9.461296e-06
# 1198        £2  1.708436e-05
# 1199        £2  3.926541e-07
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 15  of  300
# Item 16  of  300
# Item 17  of  300
# Completed posterior plots
#          Class  Post_prob
# 0     1p (new)   0.002063
# 1     1p (new)   0.001337
# 2     1p (new)   0.000777
# 3     1p (new)   0.002878
# 4     1p (new)   0.002302
# ...        ...        ...
# 1195        £2   0.000064
# 1196        £2   0.000054
# 1197        £2   0.000231
# 1198        £2   0.000014
# 1199        £2   0.000225
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 18  of  300
# Item 19  of  300
# Item 20  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  3.765278e-10
# 1     1p (new)  3.281523e-06
# 2     1p (new)  5.044774e-11
# 3     1p (new)  2.241463e-06
# 4     1p (new)  5.630858e-06
# ...        ...           ...
# 1195        £2  1.570081e-13
# 1196        £2  5.420784e-12
# 1197        £2  7.100798e-11
# 1198        £2  1.467746e-15
# 1199        £2  3.846521e-09
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 21  of  300
# Item 22  of  300
# Item 23  of  300
# Item 24  of  300
# Item 25  of  300
# Item 26  of  300
# Item 27  of  300
# Item 28  of  300
# Item 29  of  300
# Item 30  of  300
# Item 31  of  300
# Item 32  of  300
# Item 33  of  300
# Item 34  of  300
# Item 35  of  300
# Item 36  of  300
# Item 37  of  300
# Item 38  of  300
# Item 39  of  300
# Item 40  of  300
# Item 41  of  300
# Item 42  of  300
# Item 43  of  300
# Item 44  of  300
# Item 45  of  300
# Item 46  of  300
# Item 47  of  300
# Item 48  of  300
# Item 49  of  300
# Item 50  of  300
# Item 51  of  300
# Item 52  of  300
# Item 53  of  300
# Item 54  of  300
# Item 55  of  300
# Item 56  of  300
# Item 57  of  300
# Item 58  of  300
# Item 59  of  300
# Item 60  of  300
# Item 61  of  300
# Item 62  of  300
# Item 63  of  300
# Item 64  of  300
# Item 65  of  300
# Item 66  of  300
# Item 67  of  300
# Item 68  of  300
# Item 69  of  300
# Item 70  of  300
# Item 71  of  300
# Item 72  of  300
# Item 73  of  300
# Item 74  of  300
# Item 75  of  300
# Item 76  of  300
# Item 77  of  300
# Item 78  of  300
# Item 79  of  300
# Item 80  of  300
# Item 81  of  300
# Item 82  of  300
# Item 83  of  300
# Item 84  of  300
# Item 85  of  300
# Item 86  of  300
# Item 87  of  300
# Item 88  of  300
# Item 89  of  300
# Item 90  of  300
# Item 91  of  300
# Item 92  of  300
# Item 93  of  300
# Item 94  of  300
# Item 95  of  300
# Item 96  of  300
# Item 97  of  300
# Item 98  of  300
# Item 99  of  300
# Item 100  of  300
# Item 101  of  300
# Item 102  of  300
# Item 103  of  300
# Item 104  of  300
# Item 105  of  300
# Item 106  of  300
# Item 107  of  300
# Item 108  of  300
# Item 109  of  300
# Item 110  of  300
# Item 111  of  300
# Item 112  of  300
# Item 113  of  300
# Item 114  of  300
# Item 115  of  300
# Item 116  of  300
# Item 117  of  300
# Item 118  of  300
# Item 119  of  300
# Item 120  of  300
# Item 121  of  300
# Item 122  of  300
# Item 123  of  300
# Item 124  of  300
# Item 125  of  300
# Item 126  of  300
# Item 127  of  300
# Item 128  of  300
# Item 129  of  300
# Item 130  of  300
# Item 131  of  300
# Item 132  of  300
# Item 133  of  300
# Item 134  of  300
# Item 135  of  300
# Item 136  of  300
# Item 137  of  300
# Item 138  of  300
# Item 139  of  300
# Item 140  of  300
# Item 141  of  300
# Item 142  of  300
# Item 143  of  300
# Item 144  of  300
# Item 145  of  300
# Item 146  of  300
# Item 147  of  300
# Item 148  of  300
# Item 149  of  300
# Item 150  of  300
# Item 151  of  300
# Item 152  of  300
# Item 153  of  300
# Item 154  of  300
# Item 155  of  300
# Item 156  of  300
# Item 157  of  300
# Item 158  of  300
# Item 159  of  300
# Item 160  of  300
# Item 161  of  300
# Item 162  of  300
# Item 163  of  300
# Item 164  of  300
# Item 165  of  300
# Item 166  of  300
# Item 167  of  300
# Item 168  of  300
# Item 169  of  300
# Item 170  of  300
# Item 171  of  300
# Item 172  of  300
# Item 173  of  300
# Item 174  of  300
# Item 175  of  300
# Item 176  of  300
# Item 177  of  300
# Item 178  of  300
# Item 179  of  300
# Item 180  of  300
# Item 181  of  300
# Item 182  of  300
# Item 183  of  300
# Item 184  of  300
# Item 185  of  300
# Item 186  of  300
# Item 187  of  300
# Item 188  of  300
# Item 189  of  300
# Item 190  of  300
# Item 191  of  300
# Item 192  of  300
# Item 193  of  300
# Item 194  of  300
# Item 195  of  300
# Item 196  of  300
# Item 197  of  300
# Item 198  of  300
# Item 199  of  300
# Item 200  of  300
# Item 201  of  300
# Item 202  of  300
# Item 203  of  300
# Item 204  of  300
# Item 205  of  300
# Item 206  of  300
# Item 207  of  300
# Item 208  of  300
# Item 209  of  300
# Item 210  of  300
# Item 211  of  300
# Item 212  of  300
# Item 213  of  300
# Item 214  of  300
# Item 215  of  300
# Item 216  of  300
# Item 217  of  300
# Item 218  of  300
# Item 219  of  300
# Item 220  of  300
# Item 221  of  300
# Item 222  of  300
# Item 223  of  300
# Item 224  of  300
# Item 225  of  300
# Item 226  of  300
# Item 227  of  300
# Item 228  of  300
# Item 229  of  300
# Item 230  of  300
# Item 231  of  300
# Item 232  of  300
# Item 233  of  300
# Item 234  of  300
# Item 235  of  300
# Item 236  of  300
# Item 237  of  300
# Item 238  of  300
# Item 239  of  300
# Item 240  of  300
# Item 241  of  300
# Item 242  of  300
# Item 243  of  300
# Item 244  of  300
# Item 245  of  300
# Item 246  of  300
# Item 247  of  300
# Item 248  of  300
# Item 249  of  300
# Item 250  of  300
# Item 251  of  300
# Item 252  of  300
# Item 253  of  300
# Item 254  of  300
# Item 255  of  300
# Item 256  of  300
# Item 257  of  300
# Item 258  of  300
# Item 259  of  300
# Item 260  of  300
# Item 261  of  300
# Item 262  of  300
# Item 263  of  300
# Item 264  of  300
# Item 265  of  300
# Item 266  of  300
# Item 267  of  300
# Item 268  of  300
# Item 269  of  300
# Item 270  of  300
# Item 271  of  300
# Item 272  of  300
# Item 273  of  300
# Item 274  of  300
# Item 275  of  300
# Item 276  of  300
# Item 277  of  300
# Item 278  of  300
# Item 279  of  300
# Item 280  of  300
# Item 281  of  300
# Item 282  of  300
# Item 283  of  300
# Item 284  of  300
# Item 285  of  300
# Item 286  of  300
# Item 287  of  300
# Item 288  of  300
# Item 289  of  300
# Item 290  of  300
# Item 291  of  300
# Item 292  of  300
# Item 293  of  300
# Item 294  of  300
# Item 295  of  300
# Item 296  of  300
# Item 297  of  300
# Item 298  of  300
# Item 299  of  300
# Item 300  of  300
# Completed sampling
# Completed predictions
# 900 168
#  SVD complete
# Reduced the number of features from 168  to  108
# (900, 108)
# (900,)
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Plot_principal_features.py:50: UserWarning:
# The palette list has fewer values (10) than needed (12) and will cycle, which may produce an uninterpretable plot.
#   sactter_plot = sns.scatterplot(data=internal_dataframe, x='Reduced Feature 1', y = 'Reduced Feature 2', hue='Class Names', palette=palette, hue_order=reordered_names)
# Item 1  of  300
# Completed posterior plots
#          Class  Post_prob
# 0     1p (new)   0.025349
# 1     1p (new)   0.020080
# 2     1p (new)   0.001091
# 3     1p (new)   0.002738
# 4     1p (new)   0.019839
# ...        ...        ...
# 1195        £2   0.000103
# 1196        £2   0.000005
# 1197        £2   0.000212
# 1198        £2   0.002909
# 1199        £2   0.000009
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 2  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  1.379051e-08
# 1     1p (new)  9.190351e-09
# 2     1p (new)  1.130278e-06
# 3     1p (new)  4.231092e-09
# 4     1p (new)  1.714105e-07
# ...        ...           ...
# 1195        £2  4.244645e-03
# 1196        £2  4.778267e-01
# 1197        £2  2.068976e-07
# 1198        £2  4.356467e-04
# 1199        £2  1.968051e-06
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 3  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  4.650712e-14
# 1     1p (new)  3.453044e-18
# 2     1p (new)  1.947216e-08
# 3     1p (new)  1.611518e-11
# 4     1p (new)  6.663572e-12
# ...        ...           ...
# 1195        £2  1.070335e-08
# 1196        £2  3.885069e-09
# 1197        £2  5.399859e-01
# 1198        £2  3.472206e-02
# 1199        £2  9.976759e-01
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 4  of  300
# Completed posterior plots
#          Class  Post_prob
# 0     1p (new)   0.007172
# 1     1p (new)   0.010427
# 2     1p (new)   0.005508
# 3     1p (new)   0.003868
# 4     1p (new)   0.010465
# ...        ...        ...
# 1195        £2   0.000040
# 1196        £2   0.000783
# 1197        £2   0.000233
# 1198        £2   0.001556
# 1199        £2   0.000753
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 5  of  300
# Completed posterior plots
#          Class  Post_prob
# 0     1p (new)   0.003287
# 1     1p (new)   0.000561
# 2     1p (new)   0.000519
# 3     1p (new)   0.000536
# 4     1p (new)   0.002082
# ...        ...        ...
# 1195        £2   0.000009
# 1196        £2   0.000003
# 1197        £2   0.000062
# 1198        £2   0.000015
# 1199        £2   0.000005
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 6  of  300
# Completed posterior plots
#          Class  Post_prob
# 0     1p (new)   0.000346
# 1     1p (new)   0.000274
# 2     1p (new)   0.000101
# 3     1p (new)   0.000071
# 4     1p (new)   0.000332
# ...        ...        ...
# 1195        £2   0.000065
# 1196        £2   0.000088
# 1197        £2   0.001494
# 1198        £2   0.000015
# 1199        £2   0.000591
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 7  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  5.457784e-04
# 1     1p (new)  2.439796e-05
# 2     1p (new)  6.978887e-04
# 3     1p (new)  4.966216e-04
# 4     1p (new)  2.592311e-04
# ...        ...           ...
# 1195        £2  2.159745e-05
# 1196        £2  3.450537e-06
# 1197        £2  2.872560e-07
# 1198        £2  3.756012e-09
# 1199        £2  6.008948e-10
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 8  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  3.169055e-01
# 1     1p (new)  1.075069e-02
# 2     1p (new)  2.067071e-01
# 3     1p (new)  1.609799e-01
# 4     1p (new)  5.311871e-01
# ...        ...           ...
# 1195        £2  6.537982e-07
# 1196        £2  3.512941e-07
# 1197        £2  5.134345e-07
# 1198        £2  1.599925e-05
# 1199        £2  1.192213e-07
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 9  of  300
# Item 10  of  300
# Item 11  of  300
# Item 12  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  2.884663e-06
# 1     1p (new)  1.291207e-10
# 2     1p (new)  1.470055e-05
# 3     1p (new)  1.227700e-07
# 4     1p (new)  8.148904e-07
# ...        ...           ...
# 1195        £2  4.527560e-01
# 1196        £2  1.319240e-05
# 1197        £2  9.690621e-01
# 1198        £2  4.393284e-01
# 1199        £2  2.975667e-01
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 13  of  300
# Item 14  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  1.662565e-04
# 1     1p (new)  1.437341e-04
# 2     1p (new)  1.592212e-04
# 3     1p (new)  2.708304e-04
# 4     1p (new)  6.557115e-05
# ...        ...           ...
# 1195        £2  5.142117e-07
# 1196        £2  2.425387e-06
# 1197        £2  1.207394e-04
# 1198        £2  1.199412e-06
# 1199        £2  5.963478e-08
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 15  of  300
# Item 16  of  300
# Item 17  of  300
# Completed posterior plots
#          Class  Post_prob
# 0     1p (new)   0.000394
# 1     1p (new)   0.000408
# 2     1p (new)   0.001832
# 3     1p (new)   0.000690
# 4     1p (new)   0.000982
# ...        ...        ...
# 1195        £2   0.000006
# 1196        £2   0.000016
# 1197        £2   0.000005
# 1198        £2   0.000003
# 1199        £2   0.000278
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 18  of  300
# Item 19  of  300
# Item 20  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  6.631108e-10
# 1     1p (new)  2.032624e-06
# 2     1p (new)  2.413973e-10
# 3     1p (new)  4.634088e-08
# 4     1p (new)  3.499074e-08
# ...        ...           ...
# 1195        £2  3.588970e-10
# 1196        £2  3.983125e-19
# 1197        £2  2.084972e-10
# 1198        £2  1.357135e-11
# 1199        £2  2.210060e-09
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 21  of  300
# Item 22  of  300
# Item 23  of  300
# Item 24  of  300
# Item 25  of  300
# Item 26  of  300
# Item 27  of  300
# Item 28  of  300
# Item 29  of  300
# Item 30  of  300
# Item 31  of  300
# Item 32  of  300
# Item 33  of  300
# Item 34  of  300
# Item 35  of  300
# Item 36  of  300
# Item 37  of  300
# Item 38  of  300
# Item 39  of  300
# Item 40  of  300
# Item 41  of  300
# Item 42  of  300
# Item 43  of  300
# Item 44  of  300
# Item 45  of  300
# Item 46  of  300
# Item 47  of  300
# Item 48  of  300
# Item 49  of  300
# Item 50  of  300
# Item 51  of  300
# Item 52  of  300
# Item 53  of  300
# Item 54  of  300
# Item 55  of  300
# Item 56  of  300
# Item 57  of  300
# Item 58  of  300
# Item 59  of  300
# Item 60  of  300
# Item 61  of  300
# Item 62  of  300
# Item 63  of  300
# Item 64  of  300
# Item 65  of  300
# Item 66  of  300
# Item 67  of  300
# Item 68  of  300
# Item 69  of  300
# Item 70  of  300
# Item 71  of  300
# Item 72  of  300
# Item 73  of  300
# Item 74  of  300
# Item 75  of  300
# Item 76  of  300
# Item 77  of  300
# Item 78  of  300
# Item 79  of  300
# Item 80  of  300
# Item 81  of  300
# Item 82  of  300
# Item 83  of  300
# Item 84  of  300
# Item 85  of  300
# Item 86  of  300
# Item 87  of  300
# Item 88  of  300
# Item 89  of  300
# Item 90  of  300
# Item 91  of  300
# Item 92  of  300
# Item 93  of  300
# Item 94  of  300
# Item 95  of  300
# Item 96  of  300
# Item 97  of  300
# Item 98  of  300
# Item 99  of  300
# Item 100  of  300
# Item 101  of  300
# Item 102  of  300
# Item 103  of  300
# Item 104  of  300
# Item 105  of  300
# Item 106  of  300
# Item 107  of  300
# Item 108  of  300
# Item 109  of  300
# Item 110  of  300
# Item 111  of  300
# Item 112  of  300
# Item 113  of  300
# Item 114  of  300
# Item 115  of  300
# Item 116  of  300
# Item 117  of  300
# Item 118  of  300
# Item 119  of  300
# Item 120  of  300
# Item 121  of  300
# Item 122  of  300
# Item 123  of  300
# Item 124  of  300
# Item 125  of  300
# Item 126  of  300
# Item 127  of  300
# Item 128  of  300
# Item 129  of  300
# Item 130  of  300
# Item 131  of  300
# Item 132  of  300
# Item 133  of  300
# Item 134  of  300
# Item 135  of  300
# Item 136  of  300
# Item 137  of  300
# Item 138  of  300
# Item 139  of  300
# Item 140  of  300
# Item 141  of  300
# Item 142  of  300
# Item 143  of  300
# Item 144  of  300
# Item 145  of  300
# Item 146  of  300
# Item 147  of  300
# Item 148  of  300
# Item 149  of  300
# Item 150  of  300
# Item 151  of  300
# Item 152  of  300
# Item 153  of  300
# Item 154  of  300
# Item 155  of  300
# Item 156  of  300
# Item 157  of  300
# Item 158  of  300
# Item 159  of  300
# Item 160  of  300
# Item 161  of  300
# Item 162  of  300
# Item 163  of  300
# Item 164  of  300
# Item 165  of  300
# Item 166  of  300
# Item 167  of  300
# Item 168  of  300
# Item 169  of  300
# Item 170  of  300
# Item 171  of  300
# Item 172  of  300
# Item 173  of  300
# Item 174  of  300
# Item 175  of  300
# Item 176  of  300
# Item 177  of  300
# Item 178  of  300
# Item 179  of  300
# Item 180  of  300
# Item 181  of  300
# Item 182  of  300
# Item 183  of  300
# Item 184  of  300
# Item 185  of  300
# Item 186  of  300
# Item 187  of  300
# Item 188  of  300
# Item 189  of  300
# Item 190  of  300
# Item 191  of  300
# Item 192  of  300
# Item 193  of  300
# Item 194  of  300
# Item 195  of  300
# Item 196  of  300
# Item 197  of  300
# Item 198  of  300
# Item 199  of  300
# Item 200  of  300
# Item 201  of  300
# Item 202  of  300
# Item 203  of  300
# Item 204  of  300
# Item 205  of  300
# Item 206  of  300
# Item 207  of  300
# Item 208  of  300
# Item 209  of  300
# Item 210  of  300
# Item 211  of  300
# Item 212  of  300
# Item 213  of  300
# Item 214  of  300
# Item 215  of  300
# Item 216  of  300
# Item 217  of  300
# Item 218  of  300
# Item 219  of  300
# Item 220  of  300
# Item 221  of  300
# Item 222  of  300
# Item 223  of  300
# Item 224  of  300
# Item 225  of  300
# Item 226  of  300
# Item 227  of  300
# Item 228  of  300
# Item 229  of  300
# Item 230  of  300
# Item 231  of  300
# Item 232  of  300
# Item 233  of  300
# Item 234  of  300
# Item 235  of  300
# Item 236  of  300
# Item 237  of  300
# Item 238  of  300
# Item 239  of  300
# Item 240  of  300
# Item 241  of  300
# Item 242  of  300
# Item 243  of  300
# Item 244  of  300
# Item 245  of  300
# Item 246  of  300
# Item 247  of  300
# Item 248  of  300
# Item 249  of  300
# Item 250  of  300
# Item 251  of  300
# Item 252  of  300
# Item 253  of  300
# Item 254  of  300
# Item 255  of  300
# Item 256  of  300
# Item 257  of  300
# Item 258  of  300
# Item 259  of  300
# Item 260  of  300
# Item 261  of  300
# Item 262  of  300
# Item 263  of  300
# Item 264  of  300
# Item 265  of  300
# Item 266  of  300
# Item 267  of  300
# Item 268  of  300
# Item 269  of  300
# Item 270  of  300
# Item 271  of  300
# Item 272  of  300
# Item 273  of  300
# Item 274  of  300
# Item 275  of  300
# Item 276  of  300
# Item 277  of  300
# Item 278  of  300
# Item 279  of  300
# Item 280  of  300
# Item 281  of  300
# Item 282  of  300
# Item 283  of  300
# Item 284  of  300
# Item 285  of  300
# Item 286  of  300
# Item 287  of  300
# Item 288  of  300
# Item 289  of  300
# Item 290  of  300
# Item 291  of  300
# Item 292  of  300
# Item 293  of  300
# Item 294  of  300
# Item 295  of  300
# Item 296  of  300
# Item 297  of  300
# Item 298  of  300
# Item 299  of  300
# Item 300  of  300
# Completed sampling
# Completed predictions
# 900 168
#  SVD complete
# Reduced the number of features from 168  to  108
# (900, 108)
# (900,)
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Plot_principal_features.py:50: UserWarning:
# The palette list has fewer values (10) than needed (12) and will cycle, which may produce an uninterpretable plot.
#   sactter_plot = sns.scatterplot(data=internal_dataframe, x='Reduced Feature 1', y = 'Reduced Feature 2', hue='Class Names', palette=palette, hue_order=reordered_names)
# Item 1  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  5.180132e-03
# 1     1p (new)  1.183505e-02
# 2     1p (new)  3.538874e-03
# 3     1p (new)  1.292215e-02
# 4     1p (new)  1.884186e-03
# ...        ...           ...
# 1195        £2  7.512885e-06
# 1196        £2  6.078146e-06
# 1197        £2  5.032501e-06
# 1198        £2  4.632982e-04
# 1199        £2  9.870971e-08
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 2  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  9.919603e-09
# 1     1p (new)  1.815865e-05
# 2     1p (new)  1.967703e-11
# 3     1p (new)  2.853917e-08
# 4     1p (new)  4.235855e-06
# ...        ...           ...
# 1195        £2  7.793731e-06
# 1196        £2  3.877498e-04
# 1197        £2  3.447092e-03
# 1198        £2  9.535120e-01
# 1199        £2  8.616543e-07
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 3  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  2.227573e-19
# 1     1p (new)  3.738276e-11
# 2     1p (new)  2.960165e-19
# 3     1p (new)  6.143947e-16
# 4     1p (new)  2.264883e-09
# ...        ...           ...
# 1195        £2  6.522243e-04
# 1196        £2  1.290001e-02
# 1197        £2  2.584829e-07
# 1198        £2  8.152772e-01
# 1199        £2  1.664059e-06
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 4  of  300
# Completed posterior plots
#          Class  Post_prob
# 0     1p (new)   0.012867
# 1     1p (new)   0.000793
# 2     1p (new)   0.000419
# 3     1p (new)   0.007249
# 4     1p (new)   0.003272
# ...        ...        ...
# 1195        £2   0.003412
# 1196        £2   0.000027
# 1197        £2   0.000358
# 1198        £2   0.000916
# 1199        £2   0.000203
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 5  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  7.544926e-05
# 1     1p (new)  4.064837e-04
# 2     1p (new)  1.378730e-04
# 3     1p (new)  1.943235e-04
# 4     1p (new)  1.078117e-04
# ...        ...           ...
# 1195        £2  7.596432e-07
# 1196        £2  2.264433e-06
# 1197        £2  6.234147e-06
# 1198        £2  1.626442e-06
# 1199        £2  1.359618e-06
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 6  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  1.144574e-05
# 1     1p (new)  5.114582e-05
# 2     1p (new)  4.123041e-07
# 3     1p (new)  4.354594e-06
# 4     1p (new)  4.443736e-05
# ...        ...           ...
# 1195        £2  2.713125e-04
# 1196        £2  4.455263e-06
# 1197        £2  1.416471e-05
# 1198        £2  3.037146e-05
# 1199        £2  4.671982e-07
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 7  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  3.308929e-04
# 1     1p (new)  9.891693e-06
# 2     1p (new)  4.475459e-05
# 3     1p (new)  4.290151e-07
# 4     1p (new)  5.746261e-04
# ...        ...           ...
# 1195        £2  3.966814e-09
# 1196        £2  1.096734e-08
# 1197        £2  6.629168e-08
# 1198        £2  2.847263e-11
# 1199        £2  1.091341e-09
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 8  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  7.152040e-02
# 1     1p (new)  2.589487e-01
# 2     1p (new)  3.052692e-01
# 3     1p (new)  1.165849e-04
# 4     1p (new)  5.303666e-03
# ...        ...           ...
# 1195        £2  4.229988e-04
# 1196        £2  1.722443e-05
# 1197        £2  1.150846e-04
# 1198        £2  1.092468e-05
# 1199        £2  4.439068e-07
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 9  of  300
# Item 10  of  300
# Item 11  of  300
# Item 12  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  1.205638e-06
# 1     1p (new)  2.487358e-06
# 2     1p (new)  2.027563e-08
# 3     1p (new)  6.027648e-10
# 4     1p (new)  1.425496e-10
# ...        ...           ...
# 1195        £2  9.961342e-01
# 1196        £2  3.685819e-01
# 1197        £2  9.999983e-01
# 1198        £2  3.489916e-04
# 1199        £2  2.243526e-05
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 13  of  300
# Item 14  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  7.992289e-05
# 1     1p (new)  7.754545e-07
# 2     1p (new)  1.285198e-07
# 3     1p (new)  4.007984e-06
# 4     1p (new)  2.567410e-06
# ...        ...           ...
# 1195        £2  2.165853e-10
# 1196        £2  4.384018e-09
# 1197        £2  1.023048e-09
# 1198        £2  5.005273e-09
# 1199        £2  2.859503e-11
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 15  of  300
# Item 16  of  300
# Item 17  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  3.225668e-05
# 1     1p (new)  3.973315e-05
# 2     1p (new)  1.254357e-04
# 3     1p (new)  9.190593e-06
# 4     1p (new)  1.197234e-05
# ...        ...           ...
# 1195        £2  4.162654e-08
# 1196        £2  6.407846e-07
# 1197        £2  4.551821e-08
# 1198        £2  5.172677e-08
# 1199        £2  3.264352e-06
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 18  of  300
# Item 19  of  300
# Item 20  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  1.034738e-16
# 1     1p (new)  3.582319e-19
# 2     1p (new)  1.118392e-12
# 3     1p (new)  1.184213e-16
# 4     1p (new)  7.399571e-17
# ...        ...           ...
# 1195        £2  5.574261e-13
# 1196        £2  2.655998e-18
# 1197        £2  1.917391e-25
# 1198        £2  5.541908e-20
# 1199        £2  1.052385e-17
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 21  of  300
# Item 22  of  300
# Item 23  of  300
# Item 24  of  300
# Item 25  of  300
# Item 26  of  300
# Item 27  of  300
# Item 28  of  300
# Item 29  of  300
# Item 30  of  300
# Item 31  of  300
# Item 32  of  300
# Item 33  of  300
# Item 34  of  300
# Item 35  of  300
# Item 36  of  300
# Item 37  of  300
# Item 38  of  300
# Item 39  of  300
# Item 40  of  300
# Item 41  of  300
# Item 42  of  300
# Item 43  of  300
# Item 44  of  300
# Item 45  of  300
# Item 46  of  300
# Item 47  of  300
# Item 48  of  300
# Item 49  of  300
# Item 50  of  300
# Item 51  of  300
# Item 52  of  300
# Item 53  of  300
# Item 54  of  300
# Item 55  of  300
# Item 56  of  300
# Item 57  of  300
# Item 58  of  300
# Item 59  of  300
# Item 60  of  300
# Item 61  of  300
# Item 62  of  300
# Item 63  of  300
# Item 64  of  300
# Item 65  of  300
# Item 66  of  300
# Item 67  of  300
# Item 68  of  300
# Item 69  of  300
# Item 70  of  300
# Item 71  of  300
# Item 72  of  300
# Item 73  of  300
# Item 74  of  300
# Item 75  of  300
# Item 76  of  300
# Item 77  of  300
# Item 78  of  300
# Item 79  of  300
# Item 80  of  300
# Item 81  of  300
# Item 82  of  300
# Item 83  of  300
# Item 84  of  300
# Item 85  of  300
# Item 86  of  300
# Item 87  of  300
# Item 88  of  300
# Item 89  of  300
# Item 90  of  300
# Item 91  of  300
# Item 92  of  300
# Item 93  of  300
# Item 94  of  300
# Item 95  of  300
# Item 96  of  300
# Item 97  of  300
# Item 98  of  300
# Item 99  of  300
# Item 100  of  300
# Item 101  of  300
# Item 102  of  300
# Item 103  of  300
# Item 104  of  300
# Item 105  of  300
# Item 106  of  300
# Item 107  of  300
# Item 108  of  300
# Item 109  of  300
# Item 110  of  300
# Item 111  of  300
# Item 112  of  300
# Item 113  of  300
# Item 114  of  300
# Item 115  of  300
# Item 116  of  300
# Item 117  of  300
# Item 118  of  300
# Item 119  of  300
# Item 120  of  300
# Item 121  of  300
# Item 122  of  300
# Item 123  of  300
# Item 124  of  300
# Item 125  of  300
# Item 126  of  300
# Item 127  of  300
# Item 128  of  300
# Item 129  of  300
# Item 130  of  300
# Item 131  of  300
# Item 132  of  300
# Item 133  of  300
# Item 134  of  300
# Item 135  of  300
# Item 136  of  300
# Item 137  of  300
# Item 138  of  300
# Item 139  of  300
# Item 140  of  300
# Item 141  of  300
# Item 142  of  300
# Item 143  of  300
# Item 144  of  300
# Item 145  of  300
# Item 146  of  300
# Item 147  of  300
# Item 148  of  300
# Item 149  of  300
# Item 150  of  300
# Item 151  of  300
# Item 152  of  300
# Item 153  of  300
# Item 154  of  300
# Item 155  of  300
# Item 156  of  300
# Item 157  of  300
# Item 158  of  300
# Item 159  of  300
# Item 160  of  300
# Item 161  of  300
# Item 162  of  300
# Item 163  of  300
# Item 164  of  300
# Item 165  of  300
# Item 166  of  300
# Item 167  of  300
# Item 168  of  300
# Item 169  of  300
# Item 170  of  300
# Item 171  of  300
# Item 172  of  300
# Item 173  of  300
# Item 174  of  300
# Item 175  of  300
# Item 176  of  300
# Item 177  of  300
# Item 178  of  300
# Item 179  of  300
# Item 180  of  300
# Item 181  of  300
# Item 182  of  300
# Item 183  of  300
# Item 184  of  300
# Item 185  of  300
# Item 186  of  300
# Item 187  of  300
# Item 188  of  300
# Item 189  of  300
# Item 190  of  300
# Item 191  of  300
# Item 192  of  300
# Item 193  of  300
# Item 194  of  300
# Item 195  of  300
# Item 196  of  300
# Item 197  of  300
# Item 198  of  300
# Item 199  of  300
# Item 200  of  300
# Item 201  of  300
# Item 202  of  300
# Item 203  of  300
# Item 204  of  300
# Item 205  of  300
# Item 206  of  300
# Item 207  of  300
# Item 208  of  300
# Item 209  of  300
# Item 210  of  300
# Item 211  of  300
# Item 212  of  300
# Item 213  of  300
# Item 214  of  300
# Item 215  of  300
# Item 216  of  300
# Item 217  of  300
# Item 218  of  300
# Item 219  of  300
# Item 220  of  300
# Item 221  of  300
# Item 222  of  300
# Item 223  of  300
# Item 224  of  300
# Item 225  of  300
# Item 226  of  300
# Item 227  of  300
# Item 228  of  300
# Item 229  of  300
# Item 230  of  300
# Item 231  of  300
# Item 232  of  300
# Item 233  of  300
# Item 234  of  300
# Item 235  of  300
# Item 236  of  300
# Item 237  of  300
# Item 238  of  300
# Item 239  of  300
# Item 240  of  300
# Item 241  of  300
# Item 242  of  300
# Item 243  of  300
# Item 244  of  300
# Item 245  of  300
# Item 246  of  300
# Item 247  of  300
# Item 248  of  300
# Item 249  of  300
# Item 250  of  300
# Item 251  of  300
# Item 252  of  300
# Item 253  of  300
# Item 254  of  300
# Item 255  of  300
# Item 256  of  300
# Item 257  of  300
# Item 258  of  300
# Item 259  of  300
# Item 260  of  300
# Item 261  of  300
# Item 262  of  300
# Item 263  of  300
# Item 264  of  300
# Item 265  of  300
# Item 266  of  300
# Item 267  of  300
# Item 268  of  300
# Item 269  of  300
# Item 270  of  300
# Item 271  of  300
# Item 272  of  300
# Item 273  of  300
# Item 274  of  300
# Item 275  of  300
# Item 276  of  300
# Item 277  of  300
# Item 278  of  300
# Item 279  of  300
# Item 280  of  300
# Item 281  of  300
# Item 282  of  300
# Item 283  of  300
# Item 284  of  300
# Item 285  of  300
# Item 286  of  300
# Item 287  of  300
# Item 288  of  300
# Item 289  of  300
# Item 290  of  300
# Item 291  of  300
# Item 292  of  300
# Item 293  of  300
# Item 294  of  300
# Item 295  of  300
# Item 296  of  300
# Item 297  of  300
# Item 298  of  300
# Item 299  of  300
# Item 300  of  300
# Completed sampling
# Completed predictions
#
# 0.0
# 0.0
# 0.003478298769743019
# 0.003478298769743019
# 0.019040897456897608
# 0.006981977714981405
# 0.0
# 0.04136440672017461
# 0.0
# 0.003478298769743019
# 0.0
# 0.0
# 0.003478298769743019
# 0.003478298769743019
# 0.0
# 0.051639056075294676
# 0.023656187716694525
# 0.11004710790127845
# 0.01503970131023639
# 0.0
# 0.0
# 0.003478298769743019
# 0.006981977714981405
# 0.0
# 0.0
# 0.020019309268510477
# 0.0
# 0.038791300445819896
# 0.013447209478789607
# 0.0340267473994057
# 0.003478298769743019
# 0.0
# 0.0
# 0.0034784263126293774
# 0.01124670289237617
# 0.006981977714981405
# 0.010511425321212929
# 0.0
# 0.019426493284646778
# 0.0
# 0.003478298769743019
# 0.0
# 0.01040989811822883
# 0.006981977714981405
# Noise level =  10
# (1200, 504)
# (1200, 170) (1200, 168)
# Data [[-7.25113214e-11 -1.63141836e-10 -2.90010239e-10 ...  4.14401578e-08
#    7.94693910e-08  1.35649943e-07]
#  [-7.25113214e-11 -1.63141836e-10 -2.90010239e-10 ...  7.27387811e-08
#    7.59203833e-08  7.86154184e-08]
#  [-7.25113214e-11 -1.63141836e-10 -2.90010239e-10 ...  4.12240569e-08
#    9.94329370e-08  9.31426014e-08]
#  ...
#  [ 5.78392560e-07  5.68245963e-07  5.56157557e-07 ...  4.32385960e-04
#    5.53687911e-04  6.15383704e-04]
#  [ 5.78392560e-07  5.68245963e-07  5.56157557e-07 ...  4.80999346e-04
#    5.78544549e-04  6.25623024e-04]
#  [ 5.78392560e-07  5.68245963e-07  5.56157557e-07 ...  4.39360202e-04
#    5.57306814e-04  6.16939174e-04]]
# to here
# LogisticRegression_Bayesian
# 900 168
#  SVD complete
# Reduced the number of features from 168  to  107
# (900, 107)
# (900,)
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Plot_principal_features.py:50: UserWarning:
# The palette list has fewer values (10) than needed (12) and will cycle, which may produce an uninterpretable plot.
#   sactter_plot = sns.scatterplot(data=internal_dataframe, x='Reduced Feature 1', y = 'Reduced Feature 2', hue='Class Names', palette=palette, hue_order=reordered_names)
# Item 1  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  3.674915e-13
# 1     1p (new)  5.421646e-22
# 2     1p (new)  2.430041e-13
# 3     1p (new)  4.416100e-21
# 4     1p (new)  3.034136e-10
# ...        ...           ...
# 1195        £2  3.454737e-07
# 1196        £2  1.211295e-08
# 1197        £2  3.820140e-21
# 1198        £2  2.069052e-12
# 1199        £2  6.283585e-29
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 2  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  0.000000e+00
# 1     1p (new)  0.000000e+00
# 2     1p (new)  4.121520e-07
# 3     1p (new)  4.496560e-07
# 4     1p (new)  1.178200e-06
# ...        ...           ...
# 1195        £2  9.999990e-01
# 1196        £2  8.117247e-01
# 1197        £2  1.000000e+00
# 1198        £2  1.000000e+00
# 1199        £2  1.000000e+00
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 3  of  300
# Completed posterior plots
#          Class     Post_prob
# ...
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 3  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  2.548461e-06
# 1     1p (new)  4.393964e-07
# 2     1p (new)  1.333602e-08
# 3     1p (new)  0.000000e+00
# 4     1p (new)  0.000000e+00
# ...        ...           ...
# 1195        £2  9.999977e-01
# 1196        £2  9.999990e-01
# 1197        £2  9.998487e-01
# 1198        £2  1.000000e+00
# 1199        £2  1.000000e+00
#
# [1200 rows x 2 columns]
# Item 4  of  300
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  3.048094e-09
# 1     1p (new)  9.634337e-04
# 2     1p (new)  2.858785e-06
# 3     1p (new)  2.578915e-11
# 4     1p (new)  1.014091e-07
# ...        ...           ...
# 1195        £2  9.819275e-08
# 1196        £2  5.669654e-08
# 1197        £2  1.739440e-09
# 1198        £2  2.159152e-09
# 1199        £2  2.716116e-11
#
# [1200 rows x 2 columns]
# Item 5  of  300
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Completed posterior plots
#          Class  Post_prob
# 0     1p (new)   0.000068
# 1     1p (new)   0.000129
# 2     1p (new)   0.000018
# 3     1p (new)   0.000847
# 4     1p (new)   0.000009
# ...        ...        ...
# 1195        £2   0.000033
# 1196        £2   0.000223
# 1197        £2   0.000053
# 1198        £2   0.000107
# 1199        £2   0.002133
#
# [1200 rows x 2 columns]
# Item 6  of  300
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 7  of  300
# Item 8  of  300
# Item 9  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  9.876009e-01
# 1     1p (new)  9.878176e-01
# 2     1p (new)  9.996887e-01
# 3     1p (new)  9.719729e-01
# 4     1p (new)  9.993982e-01
# ...        ...           ...
# 1195        £2  4.875139e-07
# 1196        £2  4.856797e-08
# 1197        £2  9.641670e-07
# 1198        £2  1.653910e-10
# 1199        £2  3.981770e-07
#
# [1200 rows x 2 columns]
# Item 10  of  300
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 11  of  300
# Item 12  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  4.201356e-08
# 1     1p (new)  3.758151e-07
# 2     1p (new)  5.371708e-09
# 3     1p (new)  3.213545e-07
# 4     1p (new)  6.342736e-09
# ...        ...           ...
# 1195        £2  3.139384e-04
# 1196        £2  1.364253e-06
# 1197        £2  4.354518e-08
# 1198        £2  1.080335e-07
# 1199        £2  1.231429e-06
#
# [1200 rows x 2 columns]
# Item 13  of  300
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  1.581457e-24
# 1     1p (new)  2.227967e-13
# 2     1p (new)  9.443654e-21
# 3     1p (new)  5.104355e-12
# 4     1p (new)  4.525910e-12
# ...        ...           ...
# 1195        £2  2.013666e-01
# 1196        £2  5.378704e-11
# 1197        £2  1.545023e-07
# 1198        £2  6.103745e-01
# 1199        £2  1.412839e-07
#
# [1200 rows x 2 columns]
# Item 14  of  300
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  3.571354e-09
# 1     1p (new)  1.715200e-06
# 2     1p (new)  9.164252e-09
# 3     1p (new)  5.619983e-06
# 4     1p (new)  4.144602e-14
# ...        ...           ...
# 1195        £2  8.125821e-08
# 1196        £2  3.259126e-08
# 1197        £2  2.145340e-11
# 1198        £2  4.848841e-14
# 1199        £2  8.767955e-09
#
# [1200 rows x 2 columns]
# Item 15  of  300
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 16  of  300
# Item 17  of  300
# Item 18  of  300
# Item 19  of  300
# Item 20  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  5.675461e-07
# 1     1p (new)  1.496403e-08
# 2     1p (new)  2.103932e-09
# 3     1p (new)  2.188178e-06
# 4     1p (new)  2.804034e-08
# ...        ...           ...
# 1195        £2  4.789340e-06
# 1196        £2  1.410651e-06
# 1197        £2  2.429073e-07
# 1198        £2  2.112774e-04
# 1199        £2  7.515203e-05
#
# [1200 rows x 2 columns]
# Item 21  of  300
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 22  of  300
# Item 23  of  300
# Item 24  of  300
# Item 25  of  300
# Item 26  of  300
# Item 27  of  300
# Item 28  of  300
# Item 29  of  300
# Item 30  of  300
# Item 31  of  300
# Item 32  of  300
# Item 33  of  300
# Item 34  of  300
# Item 35  of  300
# Item 36  of  300
# Item 37  of  300
# Item 38  of  300
# Item 39  of  300
# Item 40  of  300
# Item 41  of  300
# Item 42  of  300
# Item 43  of  300
# Item 44  of  300
# Item 45  of  300
# Item 46  of  300
# Item 47  of  300
# Item 48  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  1.450773e-07
# 1     1p (new)  2.386828e-06
# 2     1p (new)  1.333877e-06
# 3     1p (new)  2.392276e-07
# 4     1p (new)  2.221773e-07
# ...        ...           ...
# 1195        £2  3.795727e-07
# 1196        £2  6.357797e-11
# 1197        £2  8.903398e-09
# 1198        £2  4.159382e-09
# 1199        £2  2.488406e-11
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 49  of  300
# Item 50  of  300
# Item 51  of  300
# Item 52  of  300
# Item 53  of  300
# Item 54  of  300
# Item 55  of  300
# Completed posterior plots
#          Class     Post_prob
# 0     1p (new)  2.310924e-04
# 1     1p (new)  1.526529e-07
# 2     1p (new)  4.823671e-05
# 3     1p (new)  7.173984e-05
# 4     1p (new)  1.480867e-04
# ...        ...           ...
# 1195        £2  8.988295e-07
# 1196        £2  2.117430e-02
# 1197        £2  8.360592e-08
# 1198        £2  1.156724e-04
# 1199        £2  2.426854e-06
#
# [1200 rows x 2 columns]
# /home/paul/Coding/MPT_Classifier_Testing/MPT_Classifier/Functions/Full_UQ_bootstrap.py:264: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   # Create a violin plot
# Item 56  of  300
# Item 57  of  300
# Item 58  of  300
# Item 59  of  300
# Item 60  of  300
# Item 61  of  300
# Item 62  of  300
# Item 63  of  300
# Item 64  of  300
# Item 65  of  300
# Item 66  of  300
# Item 67  of  300
# Item 68  of  300
# Item 69  of  300
# Item 70  of  300
# Item 71  of  300
# Item 72  of  300
# Item 73  of  300
# Item 74  of  300
# Item 75  of  300
# Item 76  of  300
# Item 77  of  300
# Item 78  of  300
# Item 79  of  300
# Item 80  of  300
# Item 81  of  300
# Item 82  of  300
# Item 83  of  300
# Item 84  of  300
# Item 85  of  300
# Item 86  of  300
# Item 87  of  300
# Item 88  of  300
# Item 89  of  300
# Item 90  of  300
# Item 91  of  300
# Item 92  of  300
# Item 93  of  300
# Item 94  of  300
# Item 95  of  300
# Item 96  of  300
# Item 97  of  300
# Item 98  of  300
# Item 99  of  300
# Item 100  of  300
# Item 101  of  300
# Item 102  of  300
# Item 103  of  300
# Item 104  of  300
# Item 105  of  300
# Item 106  of  300
# Item 107  of  300
# Item 108  of  300
# Item 109  of  300
# Item 110  of  300
# Item 111  of  300
# Item 112  of  300
# Item 113  of  300
# Item 114  of  300
# Item 115  of  300
# Item 116  of  300
# Item 117  of  300
# Item 118  of  300
# Item 119  of  300
# Item 120  of  300
# Item 121  of  300
# Item 122  of  300
# Item 123  of  300
# Item 124  of  300
# Item 125  of  300
# Item 126  of  300
# Item 127  of  300
# Item 128  of  300
# Item 129  of  300
# Item 130  of  300
# Item 131  of  300
# Item 132  of  300
# Item 133  of  300
# Item 134  of  300
# Item 135  of  300
# Item 136  of  300
# Item 137  of  300
# Item 138  of  300
# Item 139  of  300
# Item 140  of  300
# Item 141  of  300
# Item 142  of  300
# Item 143  of  300
# Item 144  of  300
# Item 145  of  300
# Item 146  of  300
# Item 147  of  300
# Item 148  of  300
# Item 149  of  300
# Item 150  of  300
# Item 151  of  300
# Item 152  of  300
# Item 153  of  300
# Item 154  of  300
# Item 155  of  300
# Item 156  of  300
# Item 157  of  300
# Item 158  of  300
# Item 159  of  300
# Item 160  of  300
# Item 161  of  300
# Item 162  of  300
# Item 163  of  300
# Item 164  of  300
# Item 165  of  300
# Item 166  of  300
# Item 167  of  300
# Item 168  of  300
# Item 169  of  300
# Item 170  of  300
# Item 171  of  300
# Item 172  of  300
# Item 173  of  300
# Item 174  of  300
# Item 175  of  300
# Item 176  of  300
# Item 177  of  300
# Item 178  of  300
# Item 179  of  300
# Item 180  of  300
# Item 181  of  300
# Item 182  of  300
# Item 183  of  300
# Item 184  of  300
# Item 185  of  300
# Item 186  of  300
# Item 187  of  300
# Item 188  of  300
# Item 189  of  300
# Item 190  of  300
# Item 191  of  300
# Item 192  of  300
# Item 193  of  300
# Item 194  of  300
# Item 195  of  300
# Item 196  of  300
# Item 197  of  300
# Item 198  of  300
# Item 199  of  300
# Item 200  of  300
# Item 201  of  300
# Item 202  of  300
# Item 203  of  300
# Item 204  of  300
# Item 205  of  300
# Item 206  of  300
# Item 207  of  300
# Item 208  of  300
# Item 209  of  300
# Item 210  of  300
# Item 211  of  300
# Item 212  of  300
# Item 213  of  300
# Item 214  of  300
# Item 215  of  300
# Item 216  of  300
# Item 217  of  300
# Item 218  of  300
# Item 219  of  300
# Item 220  of  300
# Item 221  of  300
# Item 222  of  300
# Item 223  of  300
# Item 224  of  300
# Item 225  of  300
# Item 226  of  300
# Item 227  of  300
# Item 228  of  300
# Item 229  of  300
# Item 230  of  300
# Item 231  of  300
# Item 232  of  300
# Item 233  of  300
# Item 234  of  300
# Item 235  of  300
# Item 236  of  300
# Item 237  of  300
# Item 238  of  300
# Item 239  of  300
# Item 240  of  300
# Item 241  of  300
# Item 242  of  300
# Item 243  of  300
# Item 244  of  300
# Item 245  of  300
# Item 246  of  300
# Item 247  of  300
# Item 248  of  300
# Item 249  of  300
# Item 250  of  300
# Item 251  of  300
# Item 252  of  300
# Item 253  of  300
# Item 254  of  300
# Item 255  of  300
# Item 256  of  300
# Item 257  of  300
# Item 258  of  300
# Item 259  of  300
# Item 260  of  300
# Item 261  of  300
# Item 262  of  300
# Item 263  of  300
# Item 264  of  300
# Item 265  of  300
# Item 266  of  300
# Item 267  of  300
# Item 268  of  300
# Item 269  of  300
# Item 270  of  300
# Item 271  of  300
# Item 272  of  300
# Item 273  of  300
# Item 274  of  300
# Item 275  of  300
# Item 276  of  300
# Item 277  of  300
# Item 278  of  300
# Item 279  of  300
# Item 280  of  300
# Item 281  of  300
# Item 282  of  300
# Item 283  of  300
# Item 284  of  300
# Item 285  of  300
# Item 286  of  300
# Item 287  of  300
# Item 288  of  300
# Item 289  of  300
# Item 290  of  300
# Item 291  of  300
# Item 292  of  300
# Item 293  of  300
# Item 294  of  300
# Item 295  of  300
# Item 296  of  300
# Item 297  of  300
# Item 298  of  300
# Item 299  of  300
# Item 300  of  300
# Completed sampling
# Completed predictions
# 0.0
# 0.006981977714981405
# 0.003478298769743019
# 0.0
# 0.006981977714981405
# 0.013026401853056648
# 0.003478298769743019
# 0.011502219572017991
# 0.02768678427686217
# 0.022920889720346636
# 0.02125840692946459
# 0.003478298769743019
# 0.0
# 0.0077937875585908966
# 0.018470089770856412
# 0.010579450039774028
# 0.006931471805599453
# 0.006981977714981405
# 0.010511425321212929
# 0.013913964904801053
# 0.024427029943965218
# 0.006931471805599453
# 0.009599259829282489
# 0.0034784263126293774
# 0.0
# 0.003478298769743019
# 0.003478298769743019
# 0